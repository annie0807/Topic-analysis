# %%
import pandas as pd
data_summary = pd.read_excel('DESCRIPTION_SUMMARY_0521.xlsx')
data_year = pd.read_excel('YEAR.xlsx')

# %%
#要存model的話 save_model = 1 ; 不存的話 save_model = 0
save_model = 0

# %% [markdown]
# ## 處理data_summary欄位問題

# %%
data_summary
# Out:
#                                                     PN  \
# 0                                             10005841
# 1    cancer, colorectal cancer, melanomas, bladder ...
# 2                                              7700545
# 3                                             10414809
# 4                                             10052320
# ..                                                 ...
# 809                                            9255269
# 810                                            9949976
# 811                                           10005756
# 812                                           10011568
# 813                                           10273252
#
#                                                CONTENT  Unnamed: 2  \
# 0    A first aspect of the invention provides an ag...         NaN
# 1                                                  NaN         NaN
# 2    A first aspect of the present invention is a m...         NaN
# 3    A first aspect of the present invention provid...         NaN
# 4    According to a first aspect of the invention t...         NaN
# ..                                                 ...         ...
# 809                                               none         NaN
# 810                                               none         NaN
# 811                                               none         NaN
# 812  Problem to be Solved by the Invention\nA probl...         NaN
# 813  Technical Problem\nThe present inventors have ...         NaN
#
#      Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0           NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...
# 809         NaN         NaN         NaN         NaN         NaN
# 810         NaN         NaN         NaN         NaN         NaN
# 811         NaN         NaN         NaN         NaN         NaN
# 812         NaN         NaN         NaN         NaN         NaN
# 813         NaN         NaN         NaN         NaN         NaN
#
# [814 rows x 8 columns]

# %%
c = 0
for i in range(len(data_summary)):
    if pd.isnull(data_summary.iloc[i][1]) != True:
        c = i
        #pass
    else:
        #print(data_summary['PN'][i])
        data_summary['CONTENT'][c] += data_summary['PN'][i]
# Out:
# <ipython-input-3-bc880dc87fd3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_summary['CONTENT'][c] += data_summary['PN'][i]

# %%
data_summary.dropna(subset = ['CONTENT'], inplace=True)

# %%
data_summary
# Out:
#            PN                                            CONTENT  Unnamed: 2  \
# 0    10005841  A first aspect of the invention provides an ag...         NaN
# 2     7700545  A first aspect of the present invention is a m...         NaN
# 3    10414809  A first aspect of the present invention provid...         NaN
# 4    10052320  According to a first aspect of the invention t...         NaN
# 6     7807358  Accordingly, among the objects of the present ...         NaN
# 7     9364475  Accordingly, there is an ongoing need for new ...         NaN
# 8     9789170  Certain embodiments relate to an isolated argi...         NaN
# 9    10029018  In a first aspect, the present invention provi...         NaN
# 10    9382228  In one aspect, compounds of the Formula I are ...         NaN
# 32    9562219  In one aspect, provided herein are methods and...         NaN
# 33    9695175  In one aspect, the invention provides compound...         NaN
# 48    7709516  It is an object of the present invention to pr...         NaN
# 141   8877445  One aspect of the disclosure is a method of id...         NaN
# 142   9839646  One aspect of the present invention relates to...         NaN
# 149   8802667  One object of the invention is to provide nove...         NaN
# 224   6936583  Surprisingly, it has now been discovered and e...         NaN
# 225   8067237  The devices and methods of the invention provi...         NaN
# 226   8828452  The invention is based in part on a regional o...         NaN
# 227   7462691  The invention provides a novel prostate cell-s...         NaN
# 228   8529917  The invention provides active agents, such as ...         NaN
# 229   7175830  The invention provides advantages that were no...         NaN
# 230  10266593  The invention provides an antibody that binds ...         NaN
# 231   7638605  The invention provides human monoclonal antibo...         NaN
# 232   8333972  The inventor screened a human testis cDNA libr...         NaN
# 233   7547771  The inventors have characterized the genomic s...         NaN
# 234   7521431  The present invention is directed to siRNAs wh...         NaN
# 235   8563556  The present invention is directed to substanti...         NaN
# 244   7871617  The present invention provides antibodies, par...         NaN
# 325   8748424  The present invention provides compounds which...         NaN
# 572   7217796  The present invention provides fully human ant...         NaN
# 720   7833997  The present invention provides reduced forms o...         NaN
# 755   9382234  The present invention relates to compounds acc...         NaN
# 765   9919047  The present invention relates to methods and c...         NaN
# 766   9834565  The present invention relates to, inter alia, ...         NaN
# 769   8470314  There is a need to design modified diphtheria ...         NaN
# 770   8524742  This invention is directed to 5H-thioeno(3,4-c...         NaN
# 786   7157079  This invention provides methods of treating hy...         NaN
# 787   9062003  This invention relates to novel compounds of f...         NaN
# 802   8067173  This present invention discloses a process of ...         NaN
# 803   7060722                                               none         NaN
# 804   8158361  To summarize, the present invention provides t...         NaN
# 805   8425906                                               none         NaN
# 806   8785464                                               none         NaN
# 807   8871712                                               none         NaN
# 808   9181348  Technical Problem\nAn object of the present in...         NaN
# 809   9255269                                               none         NaN
# 810   9949976                                               none         NaN
# 811  10005756                                               none         NaN
# 812  10011568  Problem to be Solved by the Invention\nA probl...         NaN
# 813  10273252  Technical Problem\nThe present inventors have ...         NaN
#
#      Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0           NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN
# 6           NaN         NaN         NaN         NaN         NaN
# 7           NaN         NaN         NaN         NaN         NaN
# 8           NaN         NaN         NaN         NaN         NaN
# 9           NaN         NaN         NaN         NaN         NaN
# 10          NaN         NaN         NaN         NaN         NaN
# 32          NaN         NaN         NaN         NaN         NaN
# 33          NaN         NaN         NaN         NaN         NaN
# 48          NaN         NaN         NaN         NaN         NaN
# 141         NaN         NaN         NaN         NaN         NaN
# 142         NaN         NaN         NaN         NaN         NaN
# 149         NaN         NaN         NaN         NaN         NaN
# 224         NaN         NaN         NaN         NaN         NaN
# 225         NaN         NaN         NaN         NaN         NaN
# 226         NaN         NaN         NaN         NaN         NaN
# 227         NaN         NaN         NaN         NaN         NaN
# 228         NaN         NaN         NaN         NaN         NaN
# 229         NaN         NaN         NaN         NaN         NaN
# 230         NaN         NaN         NaN         NaN         NaN
# 231         NaN         NaN         NaN         NaN         NaN
# 232         NaN         NaN         NaN         NaN         NaN
# 233         NaN         NaN         NaN         NaN         NaN
# 234         NaN         NaN         NaN         NaN         NaN
# 235         NaN         NaN         NaN         NaN         NaN
# 244         NaN         NaN         NaN         NaN         NaN
# 325         NaN         NaN         NaN         NaN         NaN
# 572         NaN         NaN         NaN         NaN         NaN
# 720         NaN         NaN         NaN         NaN         NaN
# 755         NaN         NaN         NaN         NaN         NaN
# 765         NaN         NaN         NaN         NaN         NaN
# 766         NaN         NaN         NaN         NaN         NaN
# 769         NaN         NaN         NaN         NaN         NaN
# 770         NaN         NaN         NaN         NaN         NaN
# 786         NaN         NaN         NaN         NaN         NaN
# 787         NaN         NaN         NaN         NaN         NaN
# 802         NaN         NaN         NaN         NaN         NaN
# 803         NaN         NaN         NaN         NaN         NaN
# 804         NaN         NaN         NaN         NaN         NaN
# 805         NaN         NaN         NaN         NaN         NaN
# 806         NaN         NaN         NaN         NaN         NaN
# 807         NaN         NaN         NaN         NaN         NaN
# 808         NaN         NaN         NaN         NaN         NaN
# 809         NaN         NaN         NaN         NaN         NaN
# 810         NaN         NaN         NaN         NaN         NaN
# 811         NaN         NaN         NaN         NaN         NaN
# 812         NaN         NaN         NaN         NaN         NaN
# 813         NaN         NaN         NaN         NaN         NaN

# %%
data_summary_sorted = data_summary.sort_values(by=['PN']).reset_index(drop = True)

# %%
data_summary_sorted
# Out:
#           PN                                            CONTENT  Unnamed: 2  \
# 0    6936583  Surprisingly, it has now been discovered and e...         NaN
# 1    7060722                                               none         NaN
# 2    7157079  This invention provides methods of treating hy...         NaN
# 3    7175830  The invention provides advantages that were no...         NaN
# 4    7217796  The present invention provides fully human ant...         NaN
# 5    7462691  The invention provides a novel prostate cell-s...         NaN
# 6    7521431  The present invention is directed to siRNAs wh...         NaN
# 7    7547771  The inventors have characterized the genomic s...         NaN
# 8    7638605  The invention provides human monoclonal antibo...         NaN
# 9    7700545  A first aspect of the present invention is a m...         NaN
# 10   7709516  It is an object of the present invention to pr...         NaN
# 11   7807358  Accordingly, among the objects of the present ...         NaN
# 12   7833997  The present invention provides reduced forms o...         NaN
# 13   7871617  The present invention provides antibodies, par...         NaN
# 14   8067173  This present invention discloses a process of ...         NaN
# 15   8067237  The devices and methods of the invention provi...         NaN
# 16   8158361  To summarize, the present invention provides t...         NaN
# 17   8333972  The inventor screened a human testis cDNA libr...         NaN
# 18   8425906                                               none         NaN
# 19   8470314  There is a need to design modified diphtheria ...         NaN
# 20   8524742  This invention is directed to 5H-thioeno(3,4-c...         NaN
# 21   8529917  The invention provides active agents, such as ...         NaN
# 22   8563556  The present invention is directed to substanti...         NaN
# 23   8748424  The present invention provides compounds which...         NaN
# 24   8785464                                               none         NaN
# 25   8802667  One object of the invention is to provide nove...         NaN
# 26   8828452  The invention is based in part on a regional o...         NaN
# 27   8871712                                               none         NaN
# 28   8877445  One aspect of the disclosure is a method of id...         NaN
# 29   9062003  This invention relates to novel compounds of f...         NaN
# 30   9181348  Technical Problem\nAn object of the present in...         NaN
# 31   9255269                                               none         NaN
# 32   9364475  Accordingly, there is an ongoing need for new ...         NaN
# 33   9382228  In one aspect, compounds of the Formula I are ...         NaN
# 34   9382234  The present invention relates to compounds acc...         NaN
# 35   9562219  In one aspect, provided herein are methods and...         NaN
# 36   9695175  In one aspect, the invention provides compound...         NaN
# 37   9789170  Certain embodiments relate to an isolated argi...         NaN
# 38   9834565  The present invention relates to, inter alia, ...         NaN
# 39   9839646  One aspect of the present invention relates to...         NaN
# 40   9919047  The present invention relates to methods and c...         NaN
# 41   9949976                                               none         NaN
# 42  10005756                                               none         NaN
# 43  10005841  A first aspect of the invention provides an ag...         NaN
# 44  10011568  Problem to be Solved by the Invention\nA probl...         NaN
# 45  10029018  In a first aspect, the present invention provi...         NaN
# 46  10052320  According to a first aspect of the invention t...         NaN
# 47  10266593  The invention provides an antibody that binds ...         NaN
# 48  10273252  Technical Problem\nThe present inventors have ...         NaN
# 49  10414809  A first aspect of the present invention provid...         NaN
#
#     Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0          NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN         NaN
# 20         NaN         NaN         NaN         NaN         NaN
# 21         NaN         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN         NaN
# 23         NaN         NaN         NaN         NaN         NaN
# 24         NaN         NaN         NaN         NaN         NaN
# 25         NaN         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN         NaN
# 27         NaN         NaN         NaN         NaN         NaN
# 28         NaN         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN         NaN
# 30         NaN         NaN         NaN         NaN         NaN
# 31         NaN         NaN         NaN         NaN         NaN
# 32         NaN         NaN         NaN         NaN         NaN
# 33         NaN         NaN         NaN         NaN         NaN
# 34         NaN         NaN         NaN         NaN         NaN
# 35         NaN         NaN         NaN         NaN         NaN
# 36         NaN         NaN         NaN         NaN         NaN
# 37         NaN         NaN         NaN         NaN         NaN
# 38         NaN         NaN         NaN         NaN         NaN
# 39         NaN         NaN         NaN         NaN         NaN
# 40         NaN         NaN         NaN         NaN         NaN
# 41         NaN         NaN         NaN         NaN         NaN
# 42         NaN         NaN         NaN         NaN         NaN
# 43         NaN         NaN         NaN         NaN         NaN
# 44         NaN         NaN         NaN         NaN         NaN
# 45         NaN         NaN         NaN         NaN         NaN
# 46         NaN         NaN         NaN         NaN         NaN
# 47         NaN         NaN         NaN         NaN         NaN
# 48         NaN         NaN         NaN         NaN         NaN
# 49         NaN         NaN         NaN         NaN         NaN

# %% [markdown]
# ## concatenate summary and year

# %%
data_year_sorted = data_year.sort_values(by=['PN']).reset_index(drop = True)

# %%
data_text_merge = pd.DataFrame(data_summary_sorted, columns = ['CONTENT'])
data_text_merge['PN'] = data_summary_sorted['PN']
data_text_merge['YEAR'] = data_year_sorted['YEAR']

# %%
documents_merge = data_text_merge

# %%
documents_merge
# Out:
#                                               CONTENT        PN       YEAR
# 0   Surprisingly, it has now been discovered and e...   6936583 2005-08-30
# 1                                                none   7060722 2006-06-13
# 2   This invention provides methods of treating hy...   7157079 2007-01-02
# 3   The invention provides advantages that were no...   7175830 2007-02-13
# 4   The present invention provides fully human ant...   7217796 2007-05-15
# 5   The invention provides a novel prostate cell-s...   7462691 2008-12-09
# 6   The present invention is directed to siRNAs wh...   7521431 2009-04-21
# 7   The inventors have characterized the genomic s...   7547771 2009-06-16
# 8   The invention provides human monoclonal antibo...   7638605 2009-12-29
# 9   A first aspect of the present invention is a m...   7700545 2010-04-20
# 10  It is an object of the present invention to pr...   7709516 2010-05-04
# 11  Accordingly, among the objects of the present ...   7807358 2010-10-05
# 12  The present invention provides reduced forms o...   7833997 2010-11-16
# 13  The present invention provides antibodies, par...   7871617 2011-01-18
# 14  This present invention discloses a process of ...   8067173 2011-11-29
# 15  The devices and methods of the invention provi...   8067237 2011-11-29
# 16  To summarize, the present invention provides t...   8158361 2012-04-17
# 17  The inventor screened a human testis cDNA libr...   8333972 2012-12-18
# 18                                               none   8425906 2013-04-23
# 19  There is a need to design modified diphtheria ...   8470314 2013-06-25
# 20  This invention is directed to 5H-thioeno(3,4-c...   8524742 2013-09-03
# 21  The invention provides active agents, such as ...   8529917 2013-09-10
# 22  The present invention is directed to substanti...   8563556 2013-10-22
# 23  The present invention provides compounds which...   8748424 2014-06-10
# 24                                               none   8785464 2014-07-22
# 25  One object of the invention is to provide nove...   8802667 2014-08-12
# 26  The invention is based in part on a regional o...   8828452 2014-09-09
# 27                                               none   8871712 2014-10-28
# 28  One aspect of the disclosure is a method of id...   8877445 2014-11-04
# 29  This invention relates to novel compounds of f...   9062003 2015-06-23
# 30  Technical Problem\nAn object of the present in...   9181348 2015-11-10
# 31                                               none   9255269 2016-02-09
# 32  Accordingly, there is an ongoing need for new ...   9364475 2016-06-14
# 33  In one aspect, compounds of the Formula I are ...   9382228 2016-07-05
# 34  The present invention relates to compounds acc...   9382234 2016-07-05
# 35  In one aspect, provided herein are methods and...   9562219 2017-02-07
# 36  In one aspect, the invention provides compound...   9695175 2017-07-04
# 37  Certain embodiments relate to an isolated argi...   9789170 2017-10-17
# 38  The present invention relates to, inter alia, ...   9834565 2017-12-05
# 39  One aspect of the present invention relates to...   9839646 2017-12-12
# 40  The present invention relates to methods and c...   9919047 2018-03-20
# 41                                               none   9949976 2018-04-24
# 42                                               none  10005756 2018-06-26
# 43  A first aspect of the invention provides an ag...  10005841 2018-06-26
# 44  Problem to be Solved by the Invention\nA probl...  10011568 2018-07-03
# 45  In a first aspect, the present invention provi...  10029018 2018-07-24
# 46  According to a first aspect of the invention t...  10052320 2018-08-21
# 47  The invention provides an antibody that binds ...  10266593 2019-04-23
# 48  Technical Problem\nThe present inventors have ...  10273252 2019-04-30
# 49  A first aspect of the present invention provid...  10414809 2019-09-17

# %% [markdown]
# ## 3 period

# %%
year06_11 = []
year11_16 = []
year16_21 = []
for i in range(len(documents_merge.YEAR)):
    if documents_merge.iloc[i][2] <= pd.Timestamp(2010, 12, 31):
        year06_11.append(str(documents_merge.iloc[i][0]))
    elif documents_merge.iloc[i][2] <= pd.Timestamp(2015, 12, 31):
        year11_16.append(str(documents_merge.iloc[i][0]))
    elif documents_merge.iloc[i][2] <= pd.Timestamp(2021, 12, 31):
        year16_21.append(str(documents_merge.iloc[i][0]))

# %%
print(len(year06_11), len(year11_16), len(year16_21))
#13 -> 12
#18 -> 13
#19 -> 14
# Out:
# 13 18 19

# %%
df_1 = pd.DataFrame(year06_11, columns = ['summary'])
df_2 = pd.DataFrame(year11_16, columns = ['summary'])
df_3 = pd.DataFrame(year16_21, columns = ['summary'])

# %%
df_1
# Out:
#                                               summary
# 0   Surprisingly, it has now been discovered and e...
# 1                                                none
# 2   This invention provides methods of treating hy...
# 3   The invention provides advantages that were no...
# 4   The present invention provides fully human ant...
# 5   The invention provides a novel prostate cell-s...
# 6   The present invention is directed to siRNAs wh...
# 7   The inventors have characterized the genomic s...
# 8   The invention provides human monoclonal antibo...
# 9   A first aspect of the present invention is a m...
# 10  It is an object of the present invention to pr...
# 11  Accordingly, among the objects of the present ...
# 12  The present invention provides reduced forms o...

# %%
df_2
# Out:
#                                               summary
# 0   The present invention provides antibodies, par...
# 1   This present invention discloses a process of ...
# 2   The devices and methods of the invention provi...
# 3   To summarize, the present invention provides t...
# 4   The inventor screened a human testis cDNA libr...
# 5                                                none
# 6   There is a need to design modified diphtheria ...
# 7   This invention is directed to 5H-thioeno(3,4-c...
# 8   The invention provides active agents, such as ...
# 9   The present invention is directed to substanti...
# 10  The present invention provides compounds which...
# 11                                               none
# 12  One object of the invention is to provide nove...
# 13  The invention is based in part on a regional o...
# 14                                               none
# 15  One aspect of the disclosure is a method of id...
# 16  This invention relates to novel compounds of f...
# 17  Technical Problem\nAn object of the present in...

# %%
df_3
# Out:
#                                               summary
# 0                                                none
# 1   Accordingly, there is an ongoing need for new ...
# 2   In one aspect, compounds of the Formula I are ...
# 3   The present invention relates to compounds acc...
# 4   In one aspect, provided herein are methods and...
# 5   In one aspect, the invention provides compound...
# 6   Certain embodiments relate to an isolated argi...
# 7   The present invention relates to, inter alia, ...
# 8   One aspect of the present invention relates to...
# 9   The present invention relates to methods and c...
# 10                                               none
# 11                                               none
# 12  A first aspect of the invention provides an ag...
# 13  Problem to be Solved by the Invention\nA probl...
# 14  In a first aspect, the present invention provi...
# 15  According to a first aspect of the invention t...
# 16  The invention provides an antibody that binds ...
# 17  Technical Problem\nThe present inventors have ...
# 18  A first aspect of the present invention provid...

# %% [markdown]
# ## MedTerm

# %%
f = open('MedTerm.txt')
text = []
MedTerm = []
for line in f:
    text.append(line)
for i in text:
    MedTerm.append(i.split('\n', 1)[0].lower())

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2018)
import nltk
nltk.download('wordnet')
# Out:
# C:\Users\Annie\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Annie\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#lemmatize_stemming('amini')
# Out:
# 'amini'

# %%
min_len = 1

# %%
def lemmatize_stemming(text):
    # 把字詞幹化
    stemmer = SnowballStemmer('english')
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

def preprocess_term(text):
    term_lemma = []
    term_tmp = []
    result = [] 
    #print(text)
    
    for token in gensim.utils.simple_preprocess(text, min_len=min_len, max_len=35):  #tokenize
        #print(token)
        term_tmp.append((lemmatize_stemming(token)))
    term_lemma.append(' '.join(term_tmp))
    return term_lemma

# %%
MedTerm_lemma = []  #儲存詞幹化之後的MedTerms
for w in MedTerm:
    #print(preprocess(w))
    MedTerm_lemma.append(preprocess_term(w))

# %%
MedTerm_lemma_fin = []   #將MedTerms弄成跟原本的MedTerms一樣格式
for i in range(len(MedTerm_lemma)):
    for j in range(len(MedTerm_lemma[i])):
        MedTerm_lemma_fin.append(MedTerm_lemma[i][0])

# %%
 # import MWETokenizer() method from nltk 
from nltk.tokenize import MWETokenizer 
   
# Create a reference variable for Class MWETokenizer  

MedTerm_mwe = []  #將兩個以上單字組成的字詞用tuple刮在一起
#tmp = ()
for i in range(len(MedTerm_lemma_fin)):
    if len(MedTerm_lemma_fin[i].split(' '))> 1:
        tmp = ()
        tmp = tmp + tuple(MedTerm_lemma_fin[i].split(' '))
        MedTerm_mwe.append(tmp)
    else:
        MedTerm_mwe.append(MedTerm_lemma_fin[i])

# %%
#兩個以上的字用_連接
tk = MWETokenizer(MedTerm_mwe) 
MedTerm_token = []
MedTerm_token_show = []  #將長度=0的也留著(為了方便表格觀看)
for i in range(len(MedTerm_lemma_fin)):
    if len(MedTerm_lemma_fin[i]) != 0:
        MedTerm_token.append(tk.tokenize(MedTerm_lemma_fin[i].split())[0])
        MedTerm_token_show.append(tk.tokenize(MedTerm_lemma_fin[i].split())[0])       
    else:
        MedTerm_token_show.append('')
    #print(token_medterm[0])

# %%
for token in MedTerm_token:
    print(token)
# Out:
# a_adenin
# a
# a_t
# a_c
# aaa
# aaa
# aad
# aafp_american_academi_of_famili_physician
# aamc_ass_be_medic_colleg
# aanat
# aao
# aao_american_academi_of_orthopaed_surgeon
# aap
# aarskog_syndrom
# aarskog_scott_syndrom
# aas_smith_syndrom_i
# aas_smith_syndrom_ii
# ab_ovo
# ab
# abat
# abat
# abdomen
# abdomen_acut
# abdomin
# abdomin_aneurysm
# abdomin_aorta
# abdomin_aortic_aneurysm
# abdomin_caviti
# abdomin_guard
# abdomin_hysterectomi
# abdomin_muscl_defici_syndrom
# abdomin_muscl
# abdomin_pain
# abduc_nerv
# abduct
# abductor_muscl
# aberr
# aberrometri_and_wavefront_imag
# abg_arteri_blood_gas
# abiolog
# abiot
# abiotrophi
# ablat
# ablat
# ablat_endometri
# ablepharon_macrostomia
# abnorm
# abo_blood_group
# abortifaci
# abort
# abort_artifici
# abort_habitu
# abort_induc
# abort_multipl
# abort_recurr
# abort_spontan
# abort_therapeut
# abort
# abort_polio
# abr_test
# abrad
# abraham_man
# abras
# abrin
# abruptio_abruptio_placenta
# abrupt
# ab
# abscess
# abscess_breast
# abscess_perian
# abscess_peritonsillar
# abscess_skin
# absciss
# abs
# abs_danni
# absenc_of_the_breast
# absenc_of_the_nippl
# absenc_seizur
# absent_eye
# absente
# absinth
# absinth
# absolut_cd_count
# absolut_neutrophil_count
# absorb
# absorb_dose
# absorpt
# abstemi
# abstin
# abstin_period
# abus_child
# abus_elder
# abus_emot_child
# abus_physic_child
# abus_pregnanc
# abus_psycholog_child
# abus_sexual_child
# abus_steroid
# abus_substanc
# abus_verbal_child
# abus_inhal
# ac_joint
# acanthamoeba
# acanthamoeba_kerat
# acanthosi_nigrican
# acapnia
# acaricid
# acathisia
# acc
# acceler_phase_of_leukemia
# accept_daili_intak
# access
# access_of_servic
# accessori
# accessori_digest_organ
# accessori_dwell_unit
# accessori_nerv
# accessori_neuropathi
# accessori_placenta
# acclimat_to_altitud
# accommod
# accoucheur
# accoucheus
# ace_angiotensin_convert_enzym
# acei
# acellular
# acellular_vaccin
# acentr_chromosom
# aceruloplasminemia
# acetabular
# acetabular_labrum
# acetabulum
# acetaminophen
# acet
# acet_acid
# acetoacet
# aceton
# acetyl_coa
# acetyl_coenzym_a
# acetyl_phosphat
# acetylcholin
# acetylcholinesteras
# acetylcystein
# acg
# ach_acetylcholin
# achalasia
# ach_acetylcholinesteras
# achill_tendon
# achill_tendon
# achilloburs
# achillodynia
# achlorhydria
# achondrogenesi
# achondrogenesi_type_ii
# achondrogenesi_langer_saldino_type
# achondrogenesi_hypochondrogenesi_type_ii
# achondroplasia
# achoo_syndrom
# achromatopsia
# achromycin
# acid_deposit
# acid_indigest
# acid_phosphatas
# acid_rain
# acid_reflux
# acid_amino
# acid_bile
# acid_fatti
# acid_folic
# acid_nucleic
# acid_pantothen
# acid_tran_fatti
# acid_base_balanc
# acidophilus
# acidosi
# acinetobact
# acinus_pulmonari
# acl
# acl_injuri
# acn
# acn_rosacea
# acn_vulgari
# acog_amer_colleg_of_ob_gyn
# acou
# acoust
# acoust_aphasia
# acoust_nerv
# acoust_neurinoma
# acoust_neurofibromatosi
# acoust_neuroma
# acp_american_colleg_of_physician
# acquir
# acquir_deaf
# acquir_epileptiform_aphasia
# acquir_immun
# acquir_immunodefici_syndrom
# acquir_mutat
# acral_lentigin_melanoma
# acrocentr_chromosom
# acrocephalosyndactyli
# acrochordon
# acrocyanosi
# acrodermat_enteropathica
# acrodynia
# acromegali
# acromioclavicular_joint
# acromion
# acrophobia
# acrylamid
# ac_american_cancer_societi
# ac_american_colleg_of_surgeon
# actin
# actin_keratosi
# actin_purpura
# actinomycet
# activ_charcoal
# activ_leukocyt_cell_adhes_molecul
# activ_euthanasia
# activ_immun
# activ_tuberculosi
# activ_of_daili_live_adl
# activ_drug
# acu
# acuiti_test_visual
# acuiti_auditori
# acuiti_visual
# acupressur
# acupunctur
# acupuncturist
# acustimul
# acut
# acut_abdomen
# acut_angl_closur_glaucoma
# acut_bacteri_prostat
# acut_brain_syndrom
# acut_bronchiti
# acut_confusion_state
# acut_coronari_syndrom
# acut_epiglott
# acut_fatti_liver_of_pregnanc
# acut_flaccid_myeliti_afm
# acut_glomerulonephr
# acut_hiv_infect
# acut_idiopath_polyneur
# acut_ill
# acut_kidney_failur
# acut_leukemia
# acut_lymphoblast_leukemia
# acut_lymphocyt_leukemia
# acut_membran_gingiv
# acut_mountain_sick_am
# acut_myelogen_leukemia
# acut_myeloid_leukemia
# acut_myocardi_infarct
# acut_necrot_ulcer_gingiv_anug
# acut_nonlymphocyt_leukemia
# acut_otiti_media
# acut_pain
# acut_pancreat
# acut_phase_protein
# acut_phase_reactant
# acut_promyelocyt_leukemia
# acut_radiat_syndrom
# acut_renal_failur
# acut_respiratori_diseas
# acut_respiratori_distress_syndrom
# acut_stress_disord
# acut_thrombocytopen_purpura
# acut_tubular_necrosi
# acut_phase_protein
# acut_phase_protein
# acut_phase_reactant
# acyclovir
# ad_lib
# ad
# ada_american_dental_associ
# ada_american_diabet_associ
# ada_defici
# adam_s_appl
# adamantin
# adam_stoke_diseas
# adamt
# adapt_protein
# adcc_antibodi_depend_cell_mediat_cytotox
# add_attent_deficit_disord
# addict
# addict_comput
# addison_anemia
# addison_diseas
# addisonian_anemia
# addit_genet_effect
# adduct_thumb_with_mental_retard
# adduct
# adductor_muscl
# aden
# adenin_a
# aden
# adeno
# adenocarcinoma
# adenoid_cystic_carcinoma
# adenoidectomi
# adenoid
# adenoid
# adenoid_and_tonsil
# adenoma
# adenoma_colon_famili_histori
# adenomat_polyposi_coli
# adenomat_polyposi_coli_autosom_recess
# adenomyoma
# adenomyomata
# adenomyosi
# adenomyosi_uteri
# adenopathi
# adenosin
# adenosin_deaminas_ada
# adenosin_deaminas_ada_defici
# adenosin_thallium_scan
# adenosin_triphosph
# adenovirus
# adh_antidiuret_hormon
# adh_secret_inappropri
# adhd_attent_deficit_hyperact_disord
# adhes
# adhes_capsul
# adi
# adipocyt
# adiponectin
# adipos
# adipos_most_abund_gene_transcript
# adipos
# adjac
# adjuv
# adjuv_chemotherapi
# adjuv_therapi
# adl_activ_of_daili_live
# admiss
# admit_physician
# adnexa
# adopt_medicin
# adren_cortex
# adren_failur
# adren_gland
# adren_medulla
# adrenalin
# adrenoleukodystrophi
# adu
# adult_adhd
# adult_primari_liver_cancer
# adult_t_cell_leukemia
# adult_t_cell_leukemia_lymphoma
# adult_t_cell_lymphoma
# adult_onset_diabet
# adult_onset_still_diseas
# advanc_direct
# advanc_grief
# advanc_medic_direct
# advanc_matern_age
# advanc_patern_age
# adventitia
# adventiti
# advers_drug_event
# advers_drug_reaction
# advers_effect
# advers_event
# advers_reaction
# a_autom_extern_defibril
# aer_aero
# aerob
# aerob_exercis
# aeromona_hydrophila
# aerophagia
# aerophobia
# aerosinus
# aerosol
# aerosol
# aerospac_medicin
# aerot
# aerot_media
# aesculapius
# aetiolog
# afap
# affect
# affect_disord_season_sad
# affer
# affer_nerv
# affer_vessel
# affin
# afford_care_act_aca
# afip
# aflatoxin
# afo_ankl_foot_orthosi
# afp_alpha_fetoprotein
# african_american
# african_sleep_sick
# african_swine_fever
# african_tapeworm
# african_tick_typhus
# african_trypanosomiasi
# african_american
# afterbirth
# agammaglobulinemia
# age_by_decad
# age_of_mother
# age_of_father
# age_relat_deaf
# age_relat_macular_degener
# agenc_for_toxic_substanc_and_diseas_registri
# agenesi
# agenesi_of_the_corpus_callosum
# agenesi_of_the_gallbladd
# agenesi_sacral
# agent_orang
# agent_anti_infect
# agent_antibiot
# agent_antifung
# agent_antihypertens
# agent_antimicrobi
# agent_antiprotozo
# agent_antivir
# agent_tocolyt
# ageusia
# aggress
# aggress_angiomyxoma
# aggress_lymphoma
# age
# age_nation_institut_on
# agita
# agit_depress
# agnat
# agnosia
# agonist
# agonist_mainten_treatment
# agonist_lhrh
# agoraphobia
# agranulocytosi
# agranulocytosi_infantil_genet
# agreement_arbitr
# agu
# agxt
# agyrophobia
# ahc
# ahd
# aicardi_syndrom
# aid_artifici_insemin_by_donor
# aid_vibrotactil
# aid
# aid_dementia_complex
# aid_wast_syndrom
# aid_relat_complex
# aih_artifici_insemin_by_husband
# ailurophobia
# air_bag
# air_condition_lung
# airway
# airway_obstruct
# ak
# aka_abov_the_knee_amput
# akathisia
# akinesia
# akinet
# akinet_mutism
# aku
# ala
# alagill_syndrom
# alanin
# alanin_aminotransferas_alt
# alarm_clock_headach
# alb
# albert_sabin
# albin
# albin_and_hemorrhag_diathesi
# albin_oculocutan
# albino
# albright_syndrom
# albuginea
# albumen
# albumin
# albuminuria
# alcam
# alcohol
# alcohol_abus
# alcohol_abus_and_alcohol_nation_institut
# alcohol_poison
# alcohol_cardiomyopathi
# alcohol_anonym
# alcohol
# aldos_reductas_inhibitor
# aldosteron
# aldosteron
# aldrin
# alemb
# aleut_health
# alexand_diseas
# alexand_techniqu
# alexia
# algia
# algophobia
# alic_in_wonderland_syndrom
# alic_stewart
# alien_hand_syndrom
# alienist
# alimentari
# alimentari_canal
# alkalin_phosphatas
# alkalin_water
# alkaloid
# alkaloid_vinca
# alkalosi
# alkaptonuria
# alkyl_group
# allel
# allel
# allergen
# allerg_conjunct
# allerg_contact_dermat
# allerg_contact_eczema
# allerg_granulomatosi
# allerg_granulomat_angiiti
# allerg_purpura
# allerg_reaction
# allerg_rhiniti
# allerg_rhiniti_perenni
# allerg_rhiniti_season
# allerg_salut
# allerg_vascul
# allergi
# allergi_and_infecti_diseas_nation_inst
# allergi_desensit
# allergi_immunotherapi
# allergi_scratch_test
# allergi_shot
# allergi_skin_test
# allergi_to_cockroach
# allergi_cow_milk
# allergi_honey_bee
# allergi_peanut
# allergi_soy_milk
# allodynia
# alloerot
# allogen
# allogen_graft
# allograft
# allopath
# allopath
# allopath_medicin
# allopathist
# allopathi
# alm
# alogia
# alongshan_virus_alsv
# alopecia
# alopecia_areata
# alopecia_capiti_totali
# alopecia_universali
# alopecia_traumat
# alper_diseas
# alpha_blocker
# alpha_cell_pancreat
# alpha_error
# alpha_helix
# alpha_interferon
# alpha_linolen_acid
# alpha_omega_alpha
# alpha_particl
# alpha_synuclein
# alpha_thalassemia
# alpha
# alpha_antitrypsin_defici
# alpha_defensin
# alpha_et
# alpha_ethltryptamin
# alpha_fetoprotein_afp
# alpha_gal
# alpha_glucosidas_inhibitor
# alpha_linolen_acid
# alpha_synuclein
# alport_syndrom
# alprazolam
# alp
# al
# al
# al
# al
# al
# al
# al
# al
# al
# alstrom_syndrom
# alstrom_hallgren_syndrom
# alt_alanin_aminotransferas
# altern_hemiplegia
# altern_hemiplegia_of_childhood
# altern_hemiplegia_syndrom
# altern_medic_system
# altern_medicin
# altern_medicin_nation_center_for_complem
# altern_splice
# altitud_ill
# altitud_sick
# altitud_acclimat_to
# altitud_high
# aluminum
# aluminum_poison
# aluminum_toxic
# alveolar
# alveolar_hydatid_diseas
# alveolar_proteinosi
# alveolar_rhabdomyosarcoma
# alveoli
# alveol
# alveolus
# alzheim_diseas
# alzheim_diseas_earli_onset_famili
# alzheim_s_diseas
# be
# ama
# amalgam
# amastia
# amathophobia
# amaurosi_fugax
# amaurot_famili_idioci
# amazia
# ambidextr
# ambient
# ambigu_genitalia
# amblyopia
# amblyopia_nocturn
# ambro_syndrom
# ambul
# ambul
# ambulatori
# ambulatori_care
# ambulatori_eeg_electroencephalograph
# amc_arthrogryposi_multiplex_congenita
# amd
# ameba
# amebiasi
# ameb_coliti
# ameb_dysenteri
# amelanot
# amelanot_melanoma
# amelior
# amenia
# amenorrhea
# amer_colleg_of_ob_and_gyn_acog
# american_academi_of_famili_physician_aafp
# american_academi_of_orthopaed_surgeon
# american_academi_of_pediatr
# american_associ_for_advanc_of_scienc
# american_associ_of_dermatolog
# american_cancer_societi_ac
# american_colleg_of_nurs_midwiv
# american_colleg_of_physician
# american_colleg_of_surgeon_ac
# american_dental_associ_ada
# american_diabet_associ_ada
# american_dog_tick
# american_journal_of_public_health
# american_medic_associ
# american_medic_school_first
# american_psychiatr_associ
# american_sign_languag
# american_trypanosomiasi
# american_type_cultur_collect_atcc
# americium
# ame_test
# ame_bruce_n
# ami
# amin
# amini
# amini_fariborz
# amino_acid
# amino_acid_symbol
# amino_acid_branch_chain
# amino_acid_essenti
# amino_acid_nonessenti
# amino_acid
# aminotransferas
# amitriptylin
# aml
# aml
# ammonia
# ammonium_perchlor
# amnesia
# amnesia_antegrad
# amnesia_anterograd
# amnesia_retrograd
# amnesia_transient_global
# amnes_aphasia
# amnest_aphasia
# amniocentesi
# amnion
# amnioreduct
# amniot_band_syndrom
# amniot_fluid
# amniot_sac
# amoeba
# amok
# amphetamin
# amplif
# amplif_dna
# ampulla
# ampulla_of_vater
# ampullari_carcinoma
# amput
# am_acut_mountain_sick
# am_atyp_measl_syndrom
# amsler_grid
# amuck
# amusia
# amygdala
# amygdaloid
# amygdaloid_bodi
# amygdaloid_complex
# amygdaloid_nucleus
# amyl
# amylas
# amylo
# amyloid
# amyloidosi
# amyloidosi_hereditari
# amyloidosi_primari
# amyloidosi_secondari
# amyotroph_later_sclerosi_al
# amyotroph_later_sclerosi
# amyotroph_later_sclerosi
# amyotroph_later_sclerosi
# amyotroph_later_sclerosi
# amyotroph_later_sclerosi
# amyotroph_later_sclerosi
# amyotroph_later_sclerosi
# amyotroph_later_sclerosi
# an
# ana
# anaerob
# anaesthesia
# anal_atresia
# anal_fissur
# anal_fistula
# anal_incontin
# anal_itch
# anal_papilla
# anal_papilla
# analbuminemia
# analgesia
# analges
# analges_drug
# analog
# analog
# analysi
# analysi_linkag
# analyt_sensit
# analyt_specif
# anaphia
# anaphylact_shock
# anaphylactoid_purpura
# anaphylaxi
# anaplasmosi
# anaplastolog
# anapt
# anasarca
# anastomosi
# anastrozol
# anat
# anatom_orient_term
# anatom_posit
# anatom_snuffbox
# anatomi
# anatomi_in_the_bibl
# anatomi_gray_s
# anatomi_gross
# anatomi_microscop
# anatripsi
# anc
# ancylostoma_infect
# anderson_fabri_diseas
# androgen
# androgen_ablat
# androgen_insensit_syndrom_complet
# androgen_suppress
# androgen_suppress_therapi
# androgen
# android_pelvi
# androlog
# androphobia
# androstenedion
# anemia
# anemia_and_triphalang_thumb
# anemia_addison
# anemia_addisonian
# anemia_aplast
# anemia_biermer_s
# anemia_congenit
# anemia_cooley_s
# anemia_fanconi
# anemia_iron_defici
# anemia_mediterranean
# anemia_pernici
# anemia_refractori
# anemia_sickl_cell
# anem
# anencephali
# anergi
# anesthesia
# anesthesia_awar
# anesthesia_caudal_epidur
# anesthesiologist
# anesthesiolog
# anesthet
# anesthet_epidur
# anesthet_general
# anesthet_local
# anesthetist
# anetoderma
# aneuploidi
# aneurysm
# aneurysm_abdomin
# aneurysm_aortic
# aneurysm_arteri
# aneurysm_arteriosclerot
# aneurysm_atherosclerot
# aneurysm_berri
# aneurysm_brain
# aneurysm_cardiac
# aneurysm_dissect
# aneurysm_fusiform
# aneurysm_miliari
# aneurysm_racemos
# aneurysm_renal
# aneurysm_saccular
# aneurysm_thorac
# aneurysm_venous
# aneurysm_bruit
# anfinsen
# angelman_syndrom
# anger
# angiiti
# angiiti_allerg_granulomat
# angina
# angina_pectori
# angina_tracheali
# angina_exud
# angina_prinzmet
# angina_variant
# angina_vincent
# angioedema
# angioedema_hereditari
# angiogenesi
# angiogram
# angiographi
# angiographi_coronari
# angiographi_fluorescein
# angiohemophilia
# angioid_streak
# angiokeratoma_corpori_diffusum_universal
# angiomatosi_bacillari
# angiomyolipoma
# angiomyxoma_aggress
# angioneurot_edema_hereditari
# angiopathi
# angioplasti
# angiosarcoma
# angiostatin
# angiostrongyliasi
# angiostrongylus_infect
# angiotensin
# angiotensin_convert_enzym
# angiotensin_convert_enzym
# angiotensin_receptor_blocker
# angl_closur_glaucoma
# angl_closur_glaucoma_acut
# angri
# anhedonia
# anhidrosi
# anhidrot
# anilin
# anim_to_human_transplant
# anion
# anion_gap
# anisakiasi
# aniso
# aniso
# anisocoria
# anisocytosi
# anisometropia
# ankl
# ankl_block
# ankl_bone
# ankl_joint
# ankl_pain
# ankl_sprain
# ankl_syndesmosi
# ankl_twist
# ankl_foot_orthosi
# ankyloglossia
# ankylos
# ankylos
# ankylos_spondyl
# ankylosi
# ankyrin_defici
# anlag
# anlagen
# anll
# annal_of_intern_medicin
# annexin_a
# annexin_v
# annexin
# annot
# annot
# annot_genom
# annular_pancrea
# annulus
# anogenit_tract
# anomalad_klippel_feil
# anomali
# anomali_congenit
# anomali_klippel_feil
# anomia
# anom_aphasia
# anonym
# anonym_report
# anonym_test
# anophthalmia
# anorect
# anorexia
# anorexia_nervosa
# anorexia_cancer
# anorex
# anorexigen
# anorgasmia
# anorgasmi
# anoscop
# anoscopi
# anosmia
# anotia
# anovular
# anovular_menstruat
# anovulatori
# anoxia
# anox
# ant_fire
# antagonist
# antean
# antegrad
# antegrad_amnesia
# antenat_surgeri
# anterior
# anterior_chamber
# anterior_cruciat_injuri
# anterior_cruciat_ligament
# anterior_pituitari
# anterior_segment_and_fundus_photographi
# anterior_tongu
# antero
# anterograd
# anterograd_amnesia
# anterograd_memori
# anterolisthesi
# anteroposterior
# anteroposterior_ap
# anthophobia
# anthracyclin
# anthrax
# anthrax_immun
# anthrax_toxin
# anthropolog_forens
# anti_ccp
# anti
# anti_angiogenesi_drug
# anti_ccp
# anti_citrullin_antibodi
# anti_cyclic_citrullin_peptid_antibodi
# anti_emet
# anti_infect
# anti_nmda_receptor_enceph
# anti_platelet_agent
# anti_reflux_surgeri_fundopl
# antiandrogen
# antiatherogen_mutat
# antibacteri
# antibiot
# antibiot_resist
# antibiot_resist_tuberculosi
# antibodi
# antibodi_cross_reactiv
# antibodi_antinuclear
# antibodi_antithyroglobulin
# antibodi_depend_cell_mediat_cytotox
# anticholinerg
# anticip
# anticipatori_grief
# anticoagul
# anticoagul_agent
# anticonvuls
# antidepress
# antidepress_maoi
# antidepress_ssri
# antidepress_tricycl
# antidepress
# antidiabet_agent
# antidiuret_hormon_adh
# antidot
# antielastas
# antiemet
# antiestrogen
# antifreez_poison
# antifung
# antifung_agent
# antifung_drug
# antifung_medic
# antigen
# antigen_prostat_specif
# antigen_antibodi_complex
# antigen_present_cell
# antigen_drift
# antigen_shift
# antihistamin
# antihypertens
# antiinfect
# antimalari
# antimetabolit
# antimicrobi
# antimicrobi_agent
# antimicrobi_drug
# antimicrobi_medic
# antimicrobi_resist
# antimoni
# antineoplast
# antinuclear_antibodi
# antinuclear_antibodi_test
# antioxid
# antiparallel
# antiparasit
# antiphospholipid_antibodi_syndrom
# antiprotozo
# antiprotozo_drug
# antipsoriat
# antipsychot
# antipyret
# antiretrovir
# antiretrovir_therapi_art
# antisens
# antisens_dna
# antisens_drug
# antisens_mrna
# antisens_strand_rna_virus
# antisepsi
# antisept
# antisoci_person
# antisoci_person_disord
# antispasmod
# antithymocyt_globulin
# antithyroglobulin
# antithyroid_antibodi
# antithyroid_drug
# antitoxin
# antivenin
# antivir
# antivir_agent
# anton_chekhov
# antonio_maria_valsalva
# antonomasia
# antonomast
# antonomasi
# antro_duoden_motil_studi
# antrum
# ant_fire
# ant_velvet
# anug_acut_necrot_ulcer_gingiv
# anus
# anus_imperfor
# anvil
# anxa
# anxieti
# anxieti_disord
# anxieti_disord_social
# aoa
# aom
# aorta
# aorta_abdomin
# aorta_ascend
# aorta_coarctat_of_the
# aorta_descend
# aorta_thorac
# aortal
# aortic
# aortic_aneurysm
# aortic_arch
# aortic_arch_syndrom
# aortic_atresia
# aortic_dissect
# aortic_insuffici
# aortic_regurgit
# aortic_stenosi
# aortic_valv
# aortic_valv_bicuspid
# aortiti
# ap
# ap_anteroposterior
# ap_x_ray
# apa
# apc
# apc_gene
# apc_immunolog
# apc_medic
# apec_autoimmun_polyendocrinopathi
# aperi
# apert_syndrom
# apert_syndrom_acrocephalosyndactyli
# apex
# apgar
# apgar_score
# aphagia
# aphakia
# aphasia
# aphasia_acquir_epileptiform
# aphasia_amnes
# aphasia_amnest
# aphasia_anom
# aphasia_nomin
# aphasia_primari_progress
# apheresi
# aphonia
# aphrasia
# aphthous_ulcer
# apic
# apiphobia
# aplasia
# aplasia_of_the_breast
# aplast_anemia
# apl_antiphospholipid_antibodi_syndrom
# apm
# apnea
# apnea_central_sleep
# apnea_obstruct_sleep
# apneic
# apo
# apoa_i
# apoa_i_milano
# apobec_g
# apolipoprotein_a_i
# apolipoprotein_e
# apollo
# apopain
# apophenia
# apophys_calcaneus
# apoplexi
# apoptosi
# appendectomi
# appendic
# appendic_cancer
# appendic_perfor
# appendic_ruptur
# append
# appendix
# appendix_cancer
# appendix_epididymi
# appendix_epiploica
# appendix_perfor
# appendix_ruptur
# appendix_testi
# apposit
# approv_drug
# apraxia
# apraxia_of_speech
# ap_autoimmun_polyglandular_syndrom
# apt
# aqp
# aquagen_keratoderma
# aquagen_urticaria
# aquaphobia
# aquaporin
# aqueduct
# aqueduct_of_sylvius
# aqueduct_of_the_midbrain
# aqueous_humor
# arabidopsi_thaliana
# arabidopsi_thaliana_genom
# arachnodactyli
# arachnoid
# arachnophobia
# arbitr_agreement
# arbovir_enceph
# arbovirus
# arch_aortic
# arch_vertebr
# arch_zygomat
# archaea
# archaeogenet
# archaeolog
# arctic_health
# arcuat_neuron
# arcuat_nucleus
# arcus_senili
# ard
# ard
# areflexia
# arenavirida
# arenavirus
# areola
# argentaffinoma
# arginin
# argon_laser
# argon_laser_trabeculoplasti
# argyria
# arhythmia
# arimidex
# aristolochia_fangchi
# aristoloch_acid
# aristotl
# arm
# armd
# arm_forc_institut_of_patholog
# arm_tapeworm
# arm
# aromasin
# aromatas
# aromatas_inhibitor
# aromatherapi
# array_librari
# arrector_pili
# arrector_pilorum
# arrhythmia
# arrhythmia_sinus
# arrhythmia_atrial
# arrhythmia_rapid
# arrhythmia_slow
# arrhythmia_ventricular
# ar
# arsenic
# arsin
# art_antiretrovir_therapi
# artemidorus
# artemisinin
# artemsisia_annua
# arteria_femorali
# arteri_aneurysm
# arteri_blood_gas_abg
# arteri_tension
# arteri_coronari
# arteriogram
# arteriohepat_dysplasia
# arteriol
# arteriosclerosi
# arteriosclerot_aneurysm
# arteriosclerot_retinopathi
# arterioven_malform
# arterioven_malform_avm
# arter_cranial
# arter_giant_cell
# arter_takayasu
# arter_tempor
# arteri
# arteri_diseas_coronari
# arteri_spasm_coronari
# arteri_brachial
# arteri_carotid
# arteri_central_retin
# arteri_femor
# arteri_hepat
# arteri_mesenter
# arteri_ophthalm
# arteri_pulmonari
# arteri_splenic
# arteri_vertebr
# arth_and_musculoskelet_and_skin_dis_nat_l_inst
# arthr
# arthralgia
# arthriti
# arthriti_in_children
# arthriti_mutilan
# arthriti_degen
# arthriti_gout
# arthriti_lyme
# arthriti_psoriat
# arthriti_reactiv
# arthriti_reiter
# arthriti_rheumatoid
# arthriti_spondyl
# arthriti_system_onset_chronic_rheumatoid
# arthriti_system_onset_juvenil_rheumatoid
# arthro
# arthrocentesi
# arthrogram
# arthrogryposi
# arthrogryposi_multiplex_congenita_amc
# arthropathi
# arthroscop
# arthroscop
# arthroscopi
# arthrosi
# articul
# articul_disord
# articul_of_the_bodi_princip
# artifici_abort
# artifici_heart
# artifici_insemin
# artifici_insemin_by_donor_aid
# artifici_insemin_by_husband_aih
# artifici_knee
# artifici_nose
# artifici_pacemak
# artifici_pancrea
# arylalkylamin_n_acetyltransferas
# asa_drug_caution_code
# asbesto
# asbestosi
# ascariasi
# ascari
# ascend_aorta
# ascend_pathway
# ascit
# asclepius
# ascorb_acid
# ascus
# asd
# asept
# asept_bursiti
# asept_necrosi
# asexu
# asian_cholera
# asian_flu
# asian_influenza
# asl
# asn
# asot
# asp
# asparagin
# aspartam
# aspart_aminotransferas_ast
# aspart_acid
# asperg_syndrom
# asperg_s_syndrom
# aspergillosi
# aspergillus
# asphyxia
# aspi
# aspir
# aspir
# aspir_pneumonia
# aspir_fine_needl
# aspir_joint
# aspirin
# aspirin_resist
# asplenia
# asplen
# assay
# assay_cea
# assay_nse
# assembl_and_bud
# assembl_dna
# assign_of_benefit
# assist_in_die
# assist_physician_pa
# assist_live
# assist_suicid
# assist_devic
# assist_technolog
# associ
# associ_of_american_medic_colleg
# associ_vater
# ast
# astat_seizur
# asthenia
# asthen
# asthma
# asthma_suscept_gene
# asthma_exercis_induc
# asthma_miner_s
# asthma_thermal_induc
# asthmat
# astigmat
# astigmat_keratotomi
# astigmat
# astraphobia
# astrocytoma
# asymptomat
# asymptomat_infect
# asystol
# at_in_dna
# ataxia
# ataxia_telangiectasia_mutat
# ataxia_cerebellar
# ataxia_telangiectasia
# atcc_american_type_cultur_collect
# atelectasi
# atelectasi_primari
# atelectasi_secondari
# atg
# athelia
# atherectomi
# atherogenesi
# atheroma
# atherosclerosi
# atherosclerot
# atherosclerot_aneurysm
# athetosi
# athleat_feet
# athlet_foot
# athlet_s_feet
# athlet_s_foot
# athym
# athym_mous
# atkin_diet
# atlantoaxi
# atlas_and_axi_joint
# atlas_vertebra
# atloaxoid_joint
# atm
# atn
# atom
# atonia_rem_sleep
# aton
# aton_seizur
# atop
# atop_dermat
# atopi
# atp
# atresia
# atresia_anal
# atresia_aortic
# atresia_biliari
# atria
# atrial
# atrial_arrhythmia
# atrial_fib
# atrial_fibril
# atrial_flutter
# atrial_septal_defect_asd
# atrial_septum
# atriodigit_dysplasia
# atrioventricular_av
# atrioventricular_node
# atrium
# atroph_vagin
# atrophi
# atrophi_peron_muscular
# atropin
# atropin_psychosi
# atsdr
# attack_vasovag
# attent
# attent_deficit_disord_add
# attent_deficit_hyperact_disord
# attent_get
# attent
# attenu
# attenu
# attenu_famili_adenomat_polyposi
# attenu_fap
# attenu_virus
# atyp
# atyp_measl_syndrom_am
# audiogram
# audiologist
# audiolog
# audiometri
# auditori_acuiti
# auditori_aphasia
# auditori_brainstem_respons_test
# auditori_cortex
# auditori_diseas_central
# auditori_integr_train
# auditori_percept
# auditori_prosthesi
# auditori_tube
# aura
# aural_vertigo_recurr
# auricl
# auricular
# auricular_hematoma
# auscult
# austin_flint_murmur
# autism
# autist_savant
# autoantibodi
# autochthon
# autoclav
# autogen
# autograft
# autoimmun
# autoimmun_diseas
# autoimmun_hemolyt_anemia
# autoimmun_hepat
# autoimmun_lymphoprolif_syndrom_alp
# autoimmun_polyendocrinopathi
# autoimmun_polyendocrinopathi_syndrom
# autoimmun_polyglandular_syndrom_ap
# autoimmun_process
# autoimmun_thyroid_diseas
# autoimmun_thyroid
# autoimmun
# autoinnocul
# autolog
# autolog_blood_donat
# autolysi
# autom_extern_defibril
# autom_white_cell_differenti
# automat_behavior
# automat_seizur
# automat
# autonom_failur
# autonom_nervous_system
# autonom_neuropathi
# autonomi_patient
# autophobia
# autopsi
# autoradiographi
# autosom
# autosom_chromosom
# autosom_domin
# autosom_domin_hereditari_spastic_paraplegia
# autosom_domin_radial_drusen
# autosom_recess
# autosom
# autotranspl
# autotransplant
# aux
# av_atrioventricular
# av_fistula_arterioven_fistula
# av_node
# avascular_necrosi
# avascular_necrosi_of_the_femor_head
# averi
# avian_flu
# avian_influenza
# avian_tuberculosi
# avm
# avm_arterioven_malform
# avn
# avuls
# avuls
# avuncular
# axelrod
# axelrod_julius
# axial_tomographi_computer
# axilla
# axillari
# axillari_dissect
# axillari_hyperhidrosi
# axi
# axon
# ayurveda
# azoospermia
# azoosperm_medic_definit
# azotemia
# azt
# b_cell
# b_variant_gm_gangliosidosi
# b_virus
# b_a_p
# b_type_natriuret_peptid
# b_burgdorferi
# b_cepacia
# b_coli
# b_quintana
# b_i_d_on_prescript
# ba
# babesiosi
# babinski_reflex
# babinski_respons
# babinski_sign
# babi_blue
# babi_teeth
# babi_walker
# babi_fetal_alcohol_syndrom
# babysitt_s_elbow
# bacillari_angiomatosi
# bacill_calmett_guerin
# bacillophobia
# bacillus
# bacillus_anthraci
# back_pain
# back_pain_low
# backbon
# background_radiat
# bacteremia
# bacteria
# bacteri
# bacteri_artifici_chromosom
# bacteri_periton
# bacteri_prostat_acut
# bacteri_prostat_chronic
# bacteri_vaginosi
# bacteriaphobia
# bacteriocid
# bacteriolog
# bacteriophag
# bacteriostat
# bacterium
# baep_brainstem_auditori_evok_potenti
# bag_air
# baker_cyst
# baker_s_yeast
# balamuthia_mandrillari
# balanc
# balanc_acid_base
# balanc_sens_of
# balan
# balan_circin
# balanoposth
# balantidiasi
# balantidium
# bald
# bald_patchi
# ball_and_socket_joint
# balloon_angioplasti
# balloon_tamponad
# bambino
# ban_zhi_lian
# band_chromosom
# band_q
# band_of_chromosom
# bannayan_syndrom
# bar_chart
# bar_graph
# barbara_mcclintock
# barbat_skullcap
# barber_itch
# barber_say_syndrom
# bariatr
# bariatr_physician
# bariatr_surgeri
# bariatrician
# bariatr
# barium
# barium_enema
# barium_enema_x_ray
# barium_solut
# barium_swallow
# barker_horac_albert
# barlow_syndrom
# baroparesi
# barosinus
# barot
# barotrauma
# barotrauma_otic
# barotrauma_sinus
# barr_bodi
# barrett_esophagus
# barrett_s_esophagus
# bartholin_s_gland
# bartonella_quintana
# bartsoca_papa_syndrom
# bartter_syndrom
# basal_cell_carcinoma
# basal_cell_nevus_syndrom
# basal_cell
# basal_ganglia
# basal_metabol_rate
# basal_nuclei
# basal_temperatur
# basal_thermomet
# base_breast_cancer_gene
# base_excis_repair
# base_in_dna
# base_of_tongu
# base_pair
# base_sequenc
# base_sequenc_analysi
# base_pressor
# base_excis_repair
# baselin
# basement_membran
# basic_local_align_search_tool
# basilar
# basilar_fractur
# baskervill_effect
# basophil
# basophil_leukocyt
# bather_s_erupt
# bathophobia
# batten_diseas
# batter_child_syndrom
# battl_fatigu
# bay_theorem
# baylisascari
# bcc
# bcg
# bcm
# bcns
# bdd
# bead_vitreous_type_stickler_syndrom
# beal
# beal_rodney_k
# beard
# beard_ringworm
# beat_prematur
# beau_line
# beau_s_line
# beau_reil_cross_furrow
# beaufort_wind_scale
# becker_muscular_dystrophi
# beckwith_wiedemann_syndrom
# bed_blocker
# bed_bug
# bed_bug
# bed_sore
# bednet
# bedsor
# bedwet
# bee_genom
# bee_sting
# bee_sting_african
# beef_tapeworm
# beer_criteria
# beer_list
# beetl_blister
# behavior_center_moral
# behavior_therapi
# behavior_automat
# behavior_medicin
# behcet_s_diseas
# behcet_s_syndrom
# beijerinck
# beijerinck_martinus_w
# bekam
# belch
# bell
# bell_s_palsi
# bell_charl
# bell_sir_charl
# belladonna
# bellini_duct_carcinoma
# belli
# belli_button
# belli_pain
# belt_seat
# benign
# benign_intracrani_hypertens
# benign_lymphoreticulosi
# benign_melanoma
# benign_paroxysm_posit_vertigo_bppv
# benign_prostat_hyperplasia
# benign_prostat_hypertrophi
# benign_recurr_asept_mening
# benign_sleep_myoclonus
# benjamin_spock
# benzen
# benzidin
# benzo_a_pyren
# benzodiazepin
# ber
# berardinelli_seip_syndrom
# bereav
# bergamot_oil
# bergstrom
# bergstrom_sune_k
# beriberi
# beriberi_infantil
# berlin_heart
# bernard_syndrom
# bernard_christiaan
# bernard_horner_syndrom
# bernard_soulier_syndrom
# bernstein_test
# berri_aneurysm
# berserk
# berylliosi
# beryllium
# berzelius
# berzelius_jon_jacob
# beta_adrenerg_block_agent
# beta_agonist
# beta_blocker
# beta_caroten
# beta_cell
# beta_cell_pancreat
# beta_error
# beta_particl
# beta_protein
# beta_agonist
# beta_agonist
# beta_defensin
# beta_secretas
# betel_nut
# bever_hill_diet
# bezoar
# bf
# bi
# bia
# biallel
# bias
# bicarbon
# bicep
# bicornu
# bicuspid
# bicuspid_aortic_valv
# bicuspid_valv
# bicycl_helmet
# biermer_s_anemia
# bietti_crystallin_dystrophi
# bifid
# bifid_uvula
# big_bone_diseas
# big_toe_sign
# biid
# bilater
# bilater_pneumonia
# bile
# bile_acid
# bile_acid_resin
# bile_duct_cancer
# bile_sludg
# bilharzia
# bilharziasi
# biliari
# biliari_atresia
# biliari_compress
# biliari_decompress
# biliari_sand
# biliari_sludg
# bilious
# bilious
# bilirubin
# biloma
# binaur
# bing_drink
# bing_eat_disord
# binocular
# binocular_diplopia
# binocular_vision
# binocular
# binswang_diseas
# binucl
# bio
# bioactiv
# bioarchaeolog
# biochem
# biochem_aspirin_resist
# biochemistri
# bioelectr_imped_analysi
# biofeedback
# biofilm
# biofluid
# bioident_hormon_therapi
# bioinformat
# biolog_evolut
# biolog_chemistri
# biolog_respons_modifi
# biolog_safeti_level
# biolog_safeti_level
# biolog_safeti_level
# biolog_safeti_level
# biolog_therapi
# biolog_molecular
# biomagnet_therapi
# biomark
# biopsi
# biopsi_bone_marrow
# biopsi_brain
# biopsi_breast
# biopsi_endometri
# biopsi_excision
# biopsi_incision
# biopsi_liver
# biopsi_muscl
# biopsi_punch
# biopsi_sentinel_lymph_node
# biopsi_skin
# biopsi_stereotact_needl
# biosafeti
# biosafeti_level
# biotechnolog
# bioterror
# biotherapi
# biotin
# bipolar_diseas
# bipolar_disord
# bipolar_i_disord
# bipolar_ii_disord
# bird_flu
# birt_hogg_dube_syndrom
# birt_hogg_dube_syndrom
# birth_assist
# birth_cohort
# birth_companion
# birth_control
# birth_control_emerg
# birth_defect
# birth_defect_studi_of
# birth_rate
# birthmark
# bis_in_die_on_prescript
# bisexu
# bisphosphon
# biventricular_assist_devic
# bka
# black_american
# black_death
# black_eye
# black_henna
# black_lung_diseas
# black_plagu
# blackhead
# blackwel_elizabeth
# bladder
# bladder_cancer
# bladder_cancer_risk
# bladder_cathet_indwel
# bladder_infect
# bladder_inflamm
# bladder_outlet_obstruct_boo
# bladder_pain
# bladder_overact
# blade_bone
# blalock_taussig_oper
# blast
# blast_phase
# blastocyst
# blastocysti_homini
# blastocysti_infect
# blastocystosi
# blastokinin
# blastoma
# blastomyc_dermatitidi
# blastomycosi
# blast
# bleb
# blender_experi
# blephar
# blepharophimosi
# blepharoplasti
# blepharoptosi
# blepharospasm
# blight_ovum
# blind
# blind_spot
# blind_studi
# blind
# blind_legal
# blind_night
# blister
# blister_agent
# blister_beetl
# blister_blood
# blister_fever
# blister_water
# blister_agent
# block_caudal
# blocker_beta_adrenerg
# blocker_beta
# blood
# blood_bank
# blood_blister
# blood_cleaner
# blood_clot
# blood_clot
# blood_clot_estrogen_associ
# blood_count
# blood_cultur
# blood_draw
# blood_dyscrasia
# blood_glucos
# blood_group
# blood_group_abo
# blood_in_semen
# blood_in_the_eye
# blood_in_the_urin
# blood_institut_nation_heart_lung_and
# blood_ph
# blood_poison
# blood_pressur
# blood_pressur_high
# blood_pressur_low
# blood_sugar
# blood_sugar_high
# blood_sugar_low
# blood_transfus
# blood_urea_nitrogen
# blood_urinari
# blood_brain_barrier
# blood_thinner
# bloodi_nose
# bloodi_show
# bloodi_sputum
# blot_northern
# blot_southern
# blot_western
# blue_babi
# blue_babi_oper
# blue_cohosh
# blue_sclera
# blueberri_root
# blunt_affect
# blur_vision
# blush
# bm
# bmi
# bmi_calcul
# bmj
# bmp
# bmp
# bmpr_a
# bmrs_biolog_respons_modifi
# bmt
# bnp
# board_certifi
# board_elig
# bod_pod
# bodi_cell_mass
# bodi_dysmorph_disord
# bodi_fat_monitor
# bodi_fat_scale
# bodi_habitus
# bodi_hear_aid
# bodi_imag_obsess
# bodi_integr_ident_disord
# bodi_mass_index
# bodi_odor
# bodi_packer
# bodi_pack
# bodi_stuff
# bodi_surfac_area
# bodi_type
# bodi_amygdaloid
# bodi_ciliari
# bodywork
# boerhaav_s_syndrom
# bogorad_s_syndrom
# boil
# bone
# bone_cancer
# bone_cyst_aneurysm
# bone_cyst_simpl
# bone_densiti
# bone_marrow
# bone_marrow_aspir
# bone_marrow_biopsi
# bone_marrow_transplant
# bone_marrow_transplant
# bone_mass_densiti_bmd
# bone_miner_densiti
# bone_morphogenet_protein
# bone_morphogen_protein
# bone_scan
# bone_type
# bone_ankl
# bone_blade
# bone_breast
# bone_calf
# bone_carpal
# bone_coccyg
# bone_collar
# bone_cranial
# bone_cuboid
# bone_endochondr
# bone_ethmoid
# bone_frontal
# bone_giant_cell_tumor_of
# bone_heel
# bone_occipit
# bone_pariet
# bone_sesamoid
# bone_shin
# bone_sphenoid
# bone_tempor
# bone_thigh
# bone_wing
# bone_zygomat
# bone_of_the_arm_wrist_and_hand
# bone_of_the_head
# bone_of_the_leg_ankl_and_foot
# bone_of_the_skeleton
# bone_of_the_trunk
# bone_axial
# boni_syndactyli
# boni_tarsus
# boomer
# booster_shoot
# borag
# borborygmi
# borborygmus
# borderlin_person_disord
# bornholm_diseas
# borrelia
# borrelia_burgdorferi
# borrelia_myamotoi
# bos_taurus_genom
# bosma_arhinia_microphthalmia_syndrom
# botox
# bottlefe
# botulinum_toxin
# botul
# bougi
# bougienag
# boutonneus
# bovin
# bovin_genom
# bovin_tuberculosi
# bow_leg
# bowel
# bowel_cancer
# bowel_diseas_inflammatori
# bowel_disord_and_fiber
# bowel_sound
# bowen_diseas
# bp
# bp
# bpd
# bph
# bppv_benign_paroxysm_posit_vertigo
# brace_foot_drop
# brace_milwauke
# brachial_arteri
# brachial_neuriti
# brachial_palsi
# brachial_paralysi
# brachial_plexus
# brachial_plexus_palsi
# brachial_plexus_paralysi
# brachial_vein
# brachmann_de_lang_syndrom
# brachi
# brachycephali
# brachydactyli
# brachytherapi
# brachytherapi_coronari_arteri
# bradycardia
# bradykinesia
# bradykinet
# bradyphrenia
# bradypnea
# braill_system
# brain
# brain_aneurysm
# brain_anthrax
# brain_biopsi
# brain_cancer
# brain_edema
# brain_freez
# brain_hemorrhag
# brain_lesion
# brain_malleabl
# brain_plastic
# brain_stem
# brain_swell
# brain_tumor
# brain_ventricl
# brain_fornix_of_the
# brain_water_on_the
# brainerd_diarrhea
# brainstem
# brainstem_auditori_evok_potenti
# brainstem_implant
# branch_chain_ketoaciduria
# branchial_cleav_cyst
# branchial_cyst
# braxton_hick_contract
# brazelton_newborn_test
# brca_breast_cancer_gene
# brca
# brca_breast_cancer_suscept_gene
# brca
# breadbasket
# breakbon_fever
# breast
# breast_abscess
# breast_absenc
# breast_aplasia
# breast_augment
# breast_biopsi
# breast_bone
# breast_cancer
# breast_cancer_gene
# breast_cancer_gene_brca
# breast_cancer_gene_brca
# breast_cancer_metastasi_suppressor_brms
# breast_cancer_suscept_gene
# breast_cancer_famili
# breast_cancer_male
# breast_develop_earli
# breast_discharg
# breast_feed
# breast_fibroadenoma
# breast_implant
# breast_infect
# breast_lump
# breast_milk
# breast_pain
# breast_reduct
# breast_surgeon
# breast_trauma
# breast_amastia
# breast_infiltr_ductal_carcinoma_of_the
# breast_infiltr_lobular_carcinoma_of_the
# breast_paget_diseas_of
# breastfe
# breastfe_practic
# breath
# breech
# breech_birth
# breslow_thick
# bridg
# bright_s_diseas
# brill_zinsser_diseas
# brissaud_s_infantil
# british_nation_formulari
# brittl_bone_diseas
# brittl_diabet
# broca_s_area
# break_foot
# break_hip
# bromin
# bromism
# bromobenzylcyanid
# bromoderma
# bronchi
# bronchiectasi
# bronchiol
# bronchiol
# bronchiti
# bronchiti_chronic
# bronchopulmonari
# bronchopulmonari_dysplasia
# bronchopulmonari_segment
# bronchoscop
# bronchoscopi
# bronchospasm_exercis_induc
# bronchus
# brontophobia
# brook_spiegler_syndrom
# bross
# bross_irwin_dj
# brown_fat
# brown_syndrom
# brown_louis
# brown_michael_stuart
# bruce_n_ame
# bruce_protocol
# brucellosi
# brugada_syndrom
# bruis
# bruit
# brunhild_virus
# brushfield_s_spot
# bruton_agammaglobulinemia_tyrosin_kinas
# bruxism
# bsa
# bsl
# bsl
# bsl
# bsl
# bsl
# bubbl_boy_diseas
# bubo
# bubo
# bubon_plagu
# buccal_mucosa
# buerger_s_diseas
# buffalo_chest
# buffalo_hump
# bug_kiss
# bug_reduviid
# bulbar
# bulbar_conjunctiva
# bulbourethr_gland
# bulimia
# bulimia_nervosa
# bulimia_suscept_gene
# bulla
# bulla
# bullous
# bullous_pemphigoid
# bulli
# bump
# bun
# bundl
# bunion
# buprenorphin
# burkholderia_cepacia
# burkitt_lymphoma
# burkitt_s_lymphoma
# burn
# burn_treatment
# burn_first_degre
# burn_second_degre
# burn_third_degre
# burn_mouth_syndrom
# burn_urin
# burp
# bursa
# bursa
# bursal
# bursiti
# bursiti_asept
# bursiti_calcif
# bursiti_elbow
# bursiti_hip
# bursiti_knee
# bursiti_septic
# bursiti_shoulder
# bursopathi
# buruli_ulcer
# burundanga_hyoscin_hydrobromid
# buschk_diseas
# buschk_scleredema
# buschk_s_diseas
# buschk_s_scleredema
# butterbur
# butterfli_rash
# butyr_acid
# bws
# bx
# bypass
# bypass_cardiopulmonari
# bypass_coronari
# c_cytosin
# c_peptid
# c_ib
# c_peptid
# c_reactiv_protein
# c_reactiv_protein_test_crp
# c_section
# c_botulinum
# c_difficil
# c_elegan
# c_elegan_genom
# c_perfringen
# c_welchii
# c_cervic_vertebra
# c_c_cervic_vertebra
# c_cervic_vertebra
# c_cervic_vertebra
# c_cervic_vertebra
# c_cervic_vertebra
# c_cervic_vertebra
# c_cervic_vertebra
# ca
# ca
# ca
# ca
# ca
# cabbag_soup_diet
# cabg
# cabg_off_pump
# cachect
# cachet
# cachexia
# cad
# cadasil
# cadav
# cadav_wart
# cadmium
# caduceus
# caecal
# caecum
# caenorhabd_elegan_genom
# cafe_au_lait_spot
# caffein
# cage_rib
# cage_thorac
# cain_mark_of
# cal
# cal_calori
# calabresi_paul
# calamin
# calcan_spur
# calcaneocuboid_joint
# calcaneus
# calcif_bursiti
# calcif
# calcif_nonarteriosclerot_cerebr
# calcifi_granuloma
# calcinosi
# calcinosi_cuti
# calcipotrien
# calcitonin
# calcitriol
# calcium
# calcium_channel_blocker
# calcium_defici
# calcium_excess
# calculi
# calculi_renal
# calculus
# calculus_renal
# calefaci
# calf
# calf_bone
# calicivirida
# calicivirus
# calip
# calip_skin
# calla
# callos
# callus
# calor
# calor_dolor_rubor_and_tumor
# calori
# camelpox
# camisol
# camp_depend_protein_kinas
# camphechlor
# campion_thoma
# campomel_dysplasia
# campylobact_jejuni
# campylobacteriosi
# canavan_diseas
# cancer
# cancer_anorexia
# cancer_antigen
# cancer_care
# cancer_caus
# cancer_cluster
# cancer_institut_nation
# cancer_of_the_appendix
# cancer_of_the_cervix
# cancer_of_the_clitori
# cancer_of_the_labia
# cancer_of_the_pancrea
# cancer_of_the_rectum
# cancer_of_the_tongu
# cancer_of_the_vulva
# cancer_registri
# cancer_survivor
# cancer_symptom
# cancer_adult_primari_liver
# cancer_basal_cell
# cancer_bladder
# cancer_bone
# cancer_brain
# cancer_breast
# cancer_breast_famili
# cancer_breast_suscept_gene
# cancer_cervic
# cancer_cervix
# cancer_colon
# cancer_endometri
# cancer_esophag
# cancer_esophagus
# cancer_gastric
# cancer_hodgkin_diseas_adult
# cancer_islet_cell
# cancer_kidney
# cancer_larynx
# cancer_leukemia
# cancer_lung
# cancer_lymphoma_hodgkin_adult
# cancer_lymphoma_non_hodgkin
# cancer_male_breast
# cancer_malign_melanoma
# cancer_melanoma
# cancer_multipl_myeloma
# cancer_myeloma
# cancer_non_small_cell_lung
# cancer_oat_cell
# cancer_oral
# cancer_ovarian
# cancer_ovari
# cancer_pancrea
# cancer_pancreat
# cancer_papillari
# cancer_peni
# cancer_prostat
# cancer_prostat
# cancer_rectal
# cancer_skin
# cancer_small_cell_lung
# cancer_stomach
# cancer_testicl
# cancer_testicular
# cancer_thyroid
# cancer_uterin
# cancer_uterus
# cancer_womb
# candida_albican
# candida_auri
# candid_gene
# candidiasi
# candidiasi_invas
# candidiasi_oral
# canin_flu_dog_flu
# canin_genom
# canin_heartworm
# canker_sore
# cannabinoid
# cannabinoid_hyperemesi_syndrom_chs
# cannabinoid_receptor
# cannabinoid_receptor
# cannabi
# cannonbal_puls
# cannula
# capd
# capillari
# capillari
# capillari_morphogenesi_gene
# capit
# capnocytophaga_canimorsus
# cap
# capsaicin
# capsid
# capsul
# capsul_of_glisson
# capsul
# caption
# car_booster_seat
# carb
# carbapenem_resist_enterobacteriacea_cre
# carbo_load
# carbohydr
# carbohydr_intak_infant
# carbohydr
# carbol_acid
# carbon_dioxid
# carbon_dioxid_content
# carbon_monoxid_hemoglobin
# carbon_monoxid_on_houseboat
# carbon_monoxid_poison
# carbonmonoxyhemoglobin
# carboxyhemoglobin
# carboxyhemoglobinemia
# carbuncl
# carcinoembryon_antigen
# carcinogen
# carcinogen
# carcinoid_syndrom
# carcinoid_tumor
# carcinoma
# carcinoma_in_situ
# carcinoma_in_situ_squamous_cell
# carcinoma_of_the_breast_infiltr_ductal
# carcinoma_of_the_breast_infiltr_lobular
# carcinoma_of_the_tongu
# carcinoma_ampullari
# carcinoma_basal_cell
# carcinoma_hepatocellular
# carcinoma_islet_cell
# carcinoma_merkel_cell
# carcinoma_pancreat
# cardia_studi
# cardiac
# cardiac_aneurysm
# cardiac_conduct_system
# cardiac_defibril_implant
# cardiac_index
# cardiac_insuffici
# cardiac_muscl
# cardiac_myocyt
# cardiac_myxoma
# cardiac_output
# cardiac_rehabilit
# cardiac_septum
# cardiac_stress_test_exercis
# cardiac_tamponad
# cardiac_transplant
# cardiac_ventricl
# cardiac_limb_syndrom
# cardio_cutan_syndrom
# cardiologist
# cardiolog
# cardiomegali
# cardiomyopathi
# cardiomyopathi_dilat
# cardiomyopathi_doxorubicin
# cardiomyopathi_hypertroph
# cardiopathi
# cardioplegia
# cardiopulmonari
# cardiopulmonari_bypass
# cardiopulmonari_resuscit
# cardiovascular
# cardiovascular_diseas
# cardiovascular_syncop
# cardiovascular_system
# cardiovers
# cardiovert
# carditi
# care_proxi_health
# care_ambulatori
# care_critic
# care_hospic
# care_manag
# care_nail
# care_postop
# care_preoper
# cari
# carmin
# carney_complex
# carnitin_palmitoyltransferas_cpt_defici
# caroten_beta
# carotenemia
# carotenoid
# carotid
# carotid_arteri
# carotid_bodi
# carotid_endarterectomi
# carotid_stenosi
# carotid_arteri_stenosi
# carpal_bone
# carpal_tunnel_releas
# carpal_tunnel_syndrom
# carrier_test
# carrier_hemophilia
# cartilag
# cartilag_hair_hypoplasia_syndrom
# casal_ariet
# casal_ariet_jordi
# cascad
# case_fatal_percentag
# case_fatal_proport
# case_to_infect_proport
# case_to_infect_ratio
# casein
# caseous
# cashew_allergi
# caspas
# caspas
# cassett
# cast
# cast_serial
# castleman_diseas
# castrat
# cat_cri_syndrom
# cat_eye_syndrom
# cat_scan
# cat_scan_helic
# cat_scan_spiral
# cat_scratch_diseas
# cat_scratch_fever
# catabol
# catalepsi
# catalysi
# catalyst
# catamenia
# cataplasm
# cataplexi
# cataract
# cataract_surgeri
# cataract_with_poikiloderma_atrophican
# cataract_nuclear
# cataract_primari
# cataract_secondari
# cataract_supranuclear
# cataton
# catechol_o_methyltransferas
# catecholamin
# categori_storm
# categori_storm
# categori_storm
# categori_storm
# categori_storm
# categori_five_hurrican
# categori_four_hurrican
# categori_one_hurrican
# categori_three_hurrican
# categori_two_hurrican
# cathart
# cathet
# cathet_central
# cathet_central_venous
# cathet_foley
# cathet_hemodialysi
# cathet_indwel_bladder
# cathet_pulmonari_arteri
# cathet_swan_ganz
# catheter_venous
# cathexi
# cation
# cauda_equina
# cauda_equina_syndrom
# caudad
# caudal
# caudal_anesthesia
# caudal_block
# caudal_epidur_anesthesia
# caudat_nucleus
# caul
# cauliflow_ear
# cauliflow_ear_deform
# caulophyllum_thalictroid
# causalgia
# caus_of_cancer
# cauter
# caveola
# cavernoma
# cavern_hemangioma
# cavern_sinus
# cavern_sinus_syndrom
# cavern_sinus_thrombosi
# caviti
# caviti_abdomin
# cavi
# cb
# cb_receptor
# cb
# cb_receptor
# cbc
# cber
# cbt
# cc_chemokin_receptor
# cccr
# ccd_central_core_diseas_of_muscl
# ccd_cleidocrani_dysostosi
# cchf
# cck
# ccl
# ccp
# ccr
# cd
# cd
# cd_count_absolut
# cd
# cd
# cdc
# cdhr
# cdna
# cea
# cea_assay
# cecal
# cecal_volvulus
# cecum
# cedar_fever_mountain
# celebr_diet
# celiac_diseas
# celiac_diseas_adult
# celiac_sprue
# cell
# cell_clone
# cell_cycl
# cell_fusion
# cell_lineag
# cell_sorter_fluoresc_activ
# cell_suicid
# cell_therapi
# cell_alpha_pancreat
# cell_antigen_present
# cell_b
# cell_beta_pancreat
# cell_cone
# cell_delta_pancreat
# cell_fat
# cell_helper
# cell_plasma
# cell_rod
# cell_somat
# cell_stem
# cell_t
# cell_t
# cell_t_helper
# cell_totipot
# cellophan_maculopathi
# cell_germ
# cell_reproduct
# cellulit
# cellul
# cellulitus
# celsus
# cemento_ossifi_fibroma
# centenarian
# center_for_biolog_evalu_research
# center_for_devic_radiolog_health
# center_trauma
# center_for_diseas_control_and_prevent
# centigrad
# centimet_cm
# centimorgan_cm
# central
# central_auditori_process_disord
# central_cathet
# central_core_diseas
# central_core_diseas_of_muscl
# central_fovea
# central_line
# central_nervous_system_cns
# central_nervous_system_spongi_degener_of_the
# central_retin_arteri
# central_retin_vein
# central_serous_retinopathi_csr
# central_venous_cathet
# central_venous_line
# central_vision
# centrencephal_seizur
# centric_fusion_transloc
# centromer
# ceph
# cephal
# cephalgia
# cephalgia_histamin
# cephal
# cephal_disord
# cephal_disord
# cephalothorac_lipodystrophi
# cept
# cerclag
# cercopithecin_herpesvirus
# cerebellar
# cerebellar_ataxia_with_progress_dementia
# cerebellum
# cerebr
# cerebr_amyloidosi_and_spongiform_encephalopathi
# cerebr_aneurysm
# cerebr_arteri_gas_embol_cage
# cerebr_calcif_nonarteriosclerot
# cerebr_cortex
# cerebr_edema
# cerebr_fornix
# cerebr_hemispher
# cerebr_herniat
# cerebr_hypoxia
# cerebr_palsi
# cerebr_vascular
# cerebr_vascular_diseas
# cerebr_ventricl
# cerebr
# cerebrohepatoren_syndrom
# cerebrospin_fluid
# cerebrovascular
# cerebrovascular_accid
# cerebrovascular_accid_cva_prevent
# cerebrovascular_diseas
# cerebrovascular_ferrocalcinosi
# cerebrum
# certifi_midwif
# certifi_nurs_midwif
# certifi_profession_midwif
# ceruloplasmin_defici
# cervic
# cervic_cancer
# cervic_cap
# cervic_cerclag
# cervic_disc
# cervic_dysplasia
# cervic_dystocia
# cervic_intraepitheli_neoplasia
# cervic_kyphosi_postmenopaus
# cervic_laminectomi
# cervic_rib
# cervic_spondylosi
# cervic_vertebra_first
# cervic_vertebra_second
# cervic_vertebra
# cervicectomi
# cervic
# cervix
# cervix_incompet
# cesarean_section
# cesarean_section_lower_segment
# cesarean_section_vagin_birth_after
# cesarian_section
# cesarian_section_lower_segment_lscs
# cesarian_section_vagin_birth_after
# ceteri_paribus
# cf
# cfs
# cftr
# chaga_diseas
# chain_termin_codon
# chalazion
# chamber_anterior
# chamber_posterior
# chamomil
# champus
# chancr
# chancroid
# chandipura_virus
# chang_of_life
# chang_singl_base
# channel_ion
# channelopathi
# chaperon
# chap_lip
# char_syndrom
# charbon
# charcoal_activ
# charcot_mari_tooth_diseas
# charcot_wilbrand_syndrom
# chargaff_ratio
# chargaff_rule
# chargaff_s_rule
# charg_associ
# charg_syndrom
# charl_bell
# charl_d_kelman
# charl_darwin
# charley_hors
# chart_snellen_s
# chase_the_dragon
# chd
# checkpoint
# cheek
# cheiliti
# cheiroarthropathi
# chek
# chekhov
# chekhov_anton
# chemic_menopaus
# chemic_reaction
# chemic_terror
# chemo
# chemo_brain
# chemo_fog
# chemobrain
# chemoembol
# chemofog
# chemokin
# chemokin_receptor
# chemokinesi
# chemoprevent
# chemoprophylaxi
# chemoradiotherapi
# chemosens
# chemosensori
# chemosi
# chemotherapi
# chemotherapi_adjuv
# chemotherapi_topic
# chemotherapi_relat_cognit_dysfunct
# chen_zhong_wei
# cherub
# chest
# chest_cold
# chest_film
# chest_pain
# chest_x_ray
# chew_tobacco
# chf
# chicken_genom
# chicken_pox
# chickenpox
# chickenpox_immun
# chickenpox_rash
# chickenpox_vaccin
# chigger
# chikungunya_virus
# chilblain
# child_abus
# child_abus_emot
# child_abus_physic
# child_abus_psycholog
# child_abus_sexual
# child_abus_verbal
# child_develop_test
# child_health
# child_health_and_nichd
# child_injuri_mental
# child_neglect
# child_urin_infect
# childb_fever
# childbirth_assist
# childbirth_fever
# childhood
# childhood_acut_lymphoblast_leukemia
# childhood_ataxia_with_cns_hypomyelin
# childhood_liver_cancer
# childhood_transloc_leukemia
# children_of_the_dark
# children_of_the_night
# children_s_immun
# chill
# chimera
# chimeraplasti
# chimer_antigen_receptor_car_t_cell_treatment
# chin
# chines_medicin
# chines_restaur_syndrom
# chiron
# chiropract
# chiropractor
# chlamydia
# chlamydia_trachomati
# chloral_hydrat
# chlorid
# chlorin_camphen
# chloroacetophenon
# chlorobenzylidenemalononitril
# chloroform
# chloropicrin
# chloropren
# chlorpyrifo
# choana
# choana
# choanal
# choanal_atresia
# choanal_stenosi
# chocol
# choke_object_in_airway
# choke_in_children
# cholangi
# cholangiogram
# cholangiogram_intraven
# cholangiogram_iv
# cholangiographi
# cholangiographi_percutan_transhepat
# cholangiopancreatographi_endoscop_retrograd
# cholang
# cholang_primari_scleros
# cholang_scleros
# cholecalciferol
# cholecyst
# cholecystectomi
# cholecyst
# cholecystogram_oral
# cholecystokinin
# cholelithiasi
# cholera
# cholera_genom
# cholescintigraphi
# cholestasi
# cholestasi_with_peripher_pulmonari_stenosi
# cholesteatoma
# cholesterol
# cholesterol_ester_transfer_protein
# cholesterol_guidelin
# cholesterol_lower_with_fibrat
# cholesterol_bad
# cholesterol_good
# cholesterol_hdl
# cholesterol_ldl
# cholesteryl_ester_transfer_protein
# cholestin
# chondrocalcinosi
# chondrodysplasia_metaphys_mckusick_type
# chondrodystroph_myotonia
# chondrogenesi_imperfecta
# chondroitin_sulfat
# chondromalacia
# chondromalacia_patella
# chondroplasia
# chondrosarcoma
# chorda_tympani
# chorda_tendinea
# chordoma
# chorea
# chorea_senil
# chorea_sydenham_s
# chorioamnion
# chorioangioma_placent
# choriocarcinoma
# chorion
# chorion_gonadotropin_human
# chorion_villus_sampl
# choroid
# choroid_melanoma
# choroid
# chrematophobia
# christian_boehmer_anfinsen_jr
# chromaesthesia
# chromatid
# chromatin
# chromatin_model
# chromatin_model
# chromatin_remodel
# chromatin_remodel
# chromatographi_gas_gc
# chromatophobia
# chromesthesia
# chromosom
# chromosom
# chromosom_childhood_leukemia
# chromosom
# chromosom
# chromosom_p_syndrom
# chromosom_q_syndrom
# chromosom_band
# chromosom_band
# chromosom_complement
# chromosom_disord
# chromosom_duplic
# chromosom_invers
# chromosom_invers_paracentr
# chromosom_invers_pericentr
# chromosom_map
# chromosom_acentr
# chromosom_acrocentr
# chromosom_dicentr
# chromosom_marker
# chromosom_metaphas
# chromosom_x
# chromosom_y
# chromosom
# chromosom_in_multipl_miscarriag
# chronic
# chronic_arthriti_system_onset_juvenil
# chronic_bacteri_prostat
# chronic_bronchiti
# chronic_daili_headach
# chronic_diseas
# chronic_fatigu_syndrom
# chronic_glomerulonephr
# chronic_granulocyt_leukemia
# chronic_ill
# chronic_inflammatori_demyelin_polyneuropathi
# chronic_insomnia
# chronic_kidney_failur
# chronic_leukemia
# chronic_lymphocyt_leukemia
# chronic_myelocyt_leukemia
# chronic_myelogen_leukemia
# chronic_myelogen_leukemia_juvenil
# chronic_myeloid_leukemia
# chronic_obstruct_lung_diseas_cold
# chronic_obstruct_lung_diseas_global_initiativ
# chronic_obstruct_pulmonari_diseas
# chronic_otiti_externa
# chronic_pain
# chronic_pancreat
# chronic_phase
# chronic_progress_extern_ophthalmoplegia
# chronic_recurr_multi_focal_osteomyel
# chronic_renal_failur
# chronic_tamponad
# chronic_traumat_encephalopathi_cte
# chronic_wast_diseas
# chronic
# churg_strauss_syndrom
# chyle
# chylomicron
# chyme
# ci_curi
# cic
# cidal
# cide
# cider_vinegar_diet
# cigar
# cigarett
# ciguatera
# ciguatoxin
# cilia
# ciliari_bodi
# ciliari_bodi_melanoma
# ciliari_muscl
# ciliari_neuralgia
# cilium
# cinacalcet
# circadian
# circadian_rhythm_disord
# circin_balan
# circl_of_willi
# circular_breath
# circul
# circul_fetal
# circulatori
# circulatori_system
# circum
# circumcis
# circumflex
# circumjac
# cirrhosi
# cirrhosi_and_gray_matter_degener
# cism
# cisplatin
# citrovorum_factor
# citrullin
# citrullin_antibodi
# civilian_health_and_medic_program_of_the_uniform
# cl_chlorid
# cla
# clade
# clamydia
# clap
# clark_level_of_invas
# clasp_thumb_and_mental_retard
# classic_typhus
# classif_of_diseas
# claudic
# claudic_intermitt
# claudic_venous
# claustrophobia
# clavicl
# clavus
# clay_shovel_s_fractur
# cleav_lip
# cleav_palat
# cleav_palat_prosthesi
# cleav_uvula
# cleidocrani_dysostosi
# cleidocrani_dysplasia
# click_murmur_syndrom
# climacter
# clinic
# clinic_aspirin_resist
# clinic_cytogenet
# clinic_depress
# clinic_diseas
# clinic_investig
# clinic_psycholog
# clinic_research_center
# clinic_research_trial
# clinic_social_worker_licens
# clinic_trial
# clinic_trial
# clinodactyli
# clinophobia
# clip
# clitor
# clitor_amput
# clitor_cancer
# clitorectomi
# clitoridectomi
# clitori
# cll
# cloaca
# cloacal_exstrophi
# clone
# clone_bank
# clone_recombin
# clonic_seizur
# clone
# clone_vector
# clone_cell
# clone_dna
# clone_therapeut
# clonot
# clostridium
# clostridium_botulinum
# clostridium_difficil
# clostridium_perfringen
# clostridium_welchii
# clot_blood
# clot_dissolv_medic
# clotbust
# clove_syndrom
# club_drug
# clubfoot
# cluster
# cluster_headach
# cm
# cm_centimet
# cm_coccidioidomycosi
# cme
# cmg
# cml
# cml_juvenil
# cmt
# cmv_cytomegalovirus
# cnm
# cnp
# cnps
# cnr
# cnr
# cns_central_nervous_system
# cns_prophylaxi
# co_morbid
# co_payment
# co_stimul
# coagul
# coagul_laser
# coal_miner_s_pneumoconiosi
# coarctat
# coarctat_of_the_aorta
# coat_stent
# cobalamin
# cocain
# cocci
# coccidioidomycosi_cm
# coccus
# coccydynia
# coccyg
# coccyg_vertebra
# coccyx
# coccyx_bone
# cochlea
# ...
# treadmil_test
# treadmil_exercis
# treatment_palliat
# treatment_puva
# treatment_symptomat
# tremor
# trench_fever
# trench_mouth
# treponema_pallidum
# triag
# trial_clinic
# tricep
# trich_prefix
# trichina_spirali
# trichinella_spirali
# trichinellosi
# trichinosi
# trichloroethylen
# tricho_prefix
# trichobezoar
# trichoepithelioma
# trichomona
# trichomona_vaginali
# trichomoniasi
# trichotillomania
# trichuriasi
# trichuri_trichiura
# tricuspid
# tricuspid_valv
# tricycl_antidepress
# trigemin_nerv
# trigemin_neuralgia
# trigger
# triglycerid_test
# triglycerid
# triiodothyronin
# trimest
# trimethylamin_n_oxid_tmao
# trimethylaminuria_tma
# trimox
# trinucleotid
# trip
# trip_hammer_puls
# tripeptid
# triphalang
# tripl_c_s
# triplet
# triptan
# triptan_triptan
# triskaidekaphobia
# trismus
# trismus_and_pseudocamptodactyli_syndrom
# trismus_pseudocamptodactyli_syndrom
# trisomi
# trisomi_syndrom
# trisomi_syndrom
# trisomi_syndrom
# tritiat
# tritium
# trna
# trocar
# trochant
# troch
# trochlear_nerv
# tropic_cyclon
# tropic_diabet
# tropic_oil
# tropic_typhus
# trp
# true_cramp
# true_rib
# truncat
# truncat
# trunk_bone
# trunk_pulmonari
# trypanosoma_cruzi
# trypanosomiasi_african
# trypanosomiasi_american
# trypophobia
# tryptophan
# tsc
# tsc
# tsd
# tse
# tsh
# tsh_receptor
# tsi
# tsutsugamushi_diseas
# ttp_thrombot_thrombocytopen_purpura
# ttr
# tubal_occlus_procedur_select_stop
# tubal_pregnanc
# tube
# tube_feed
# tube_auditori
# tube_ear
# tube_endotrach
# tube_eustachian
# tube_fallopian
# tube_nasogastr
# tube_ng
# tube_otopharyng
# tube_swallow
# tube_tympanostomi
# tuber
# tubercl
# tubercular
# tuberculin
# tuberculosi
# tuberculosi_treatment
# tuberculosi_vaccin
# tuberculosi_activ
# tuberculosi_antibiot_resist
# tuberculosi_avian
# tuberculosi_bovin
# tuberculosi_dormant
# tuberculosi_drug_resist
# tuberculosi_extrapulmonari
# tuberculosi_genet_suscept_to
# tuberculosi_mdr
# tuberculosi_miliari
# tuberculosi_pulmonari
# tuberculot
# tubercul
# tubercul_diskiti
# tubercul_mening
# tuberoerupt_xanthoma
# tuber_sclerosi
# tuber_sclerosi
# tuber_sclerosi
# tube
# tubular_vision
# tubul
# tularemia
# tumesc
# tumesc_liposuct
# tummi
# tumor
# tumor_debulk
# tumor_grade
# tumor_marker
# tumor_marker_cea
# tumor_marker_nse
# tumor_necrosi_factor
# tumor_registri
# tumor_suppressor_gene
# tumor_carcinoid
# tumor_desmoid
# tumor_ear
# tumor_islet_cell
# tumor_malign_giant_cell
# tumor_primari
# tumor_sweat_gland
# tumor_wilm
# tuna
# tunga_penetran
# tunica_albuginea
# tunica_albuginea_of_the_testi
# tunnel_vision
# turban_tumor_syndrom
# turbin
# turbinectomi
# turcot_syndrom
# turf_toe
# turgor
# turmer
# turner_syndrom
# turner_kieser_syndrom
# tvs
# twelfth_cranial_nerv
# twenti_twenti
# twilight_sleep
# twin
# twin_vanish
# twist_ankl
# twitch
# twitch
# two_anim_rule
# two_face_twin
# txa
# txb
# tylenol
# tylosi
# tylosi_with_esophag_cancer
# tympan
# tympan_caviti
# tympan_membran
# tympanit
# tympano
# tympanometri
# tympanoplasti
# tympanostomi_tube
# tympanum
# tympani
# type_diabet
# type_gm_gangliosidosi
# type_diabet
# type_myoton_dystrophi
# type_diabet
# type_b_diabet
# type_i_error
# type_ii_error
# typhoid
# typhoid_fever
# typhoid_mari
# typhoon
# typhoon_suppli_kit
# typhus
# typhus_fever
# typhus_african_tick
# typhus_classic
# typhus_endem
# typhus_epidem
# typhus_european
# typhus_lous_bear
# typhus_mite_bear
# typhus_murin
# typhus_queensland_tick
# typhus_rat_flea
# typhus_scrub
# typhus_tick
# typhus_tropic
# typhus_urban_of_malaya
# typist_s_cramp
# tyr
# tyrosin
# tyrosinemia
# tyrosinemia_type_i
# tyrosinemia_type_ii
# tzanck_smear
# tzanck_test
# u_uracil
# u_s_nation_librari_of_medicin_nlm
# ua
# uaa
# uag
# ual
# ubidecarenon
# ubiquinon
# ubiquitin
# ubiquitin
# ubiquit
# ubt
# udp_glucuronosyltransferas
# uga
# ul
# ulcer
# ulcer_aphthous
# ulcer_buruli
# ulcer_duoden
# ulcer_esophag
# ulcer_gastric
# ulcer_peptic
# ulcer_stasi
# ulcer
# ulcer_coliti
# ulcer_gingiv
# ulcer_proctiti
# ullrich_congenit_muscular_dystrophi
# ulna
# ulnar
# ulnar_collater_ligament_injuri_of_the_elbow
# ulnar_collater_ligament_reconstruct_uclr
# ulnar_nerv
# ulocarcinoma
# ultrafast_ct
# ultrason_assist_liposuct
# ultrasound
# ultrasound_dure_pregnanc
# ultrasound_doppler
# ultrasound_endoscop
# ultrasound_transvagin
# ultrasound_ultrasonographi
# ultraviolet_a
# ultraviolet_b
# ultraviolet_c
# ultraviolet_radiat
# umami
# umbil_cord
# umbilicus
# ump
# unassist_childbirth
# uncertainti
# unconsci
# unconsci_temporari
# under_the_weather
# underload_syndrom
# underventil
# underwat_weigh
# undifferenti_cancer
# undul_fever
# undulat
# undul
# unesco
# ungui_incarnatus
# unicellular
# unicornu
# unilater
# unipar
# uniqu_identifi_report
# unit_intern_iu
# unit_network_for_organ_share_uno
# unit_state_pharmacopeia
# unit_state_public_health_servic
# univers_coliti
# univers_donor
# uno
# unresect
# unresolv_grief
# unsatur_fat
# unstabl_diabet
# unsteadi
# unwel
# up_regul
# upper_gi_seri
# upper_leg
# upper_motor_neuron
# upper_respiratori_infect
# upregul
# urachus
# uracil_u
# uranium
# urat
# urban_typhus_of_malaya
# urea
# urea_breath_test_ubt
# urea_cycl_disord
# ureaplasma
# uremia
# uret
# urethra
# urethr_meatus_femal
# urethr_open_femal
# urethr_sphincter
# urethr
# urethroscop
# urg
# urg_incontin
# urgenc_urinari
# uri
# uric_acid
# uricaciduria
# uridin_monophosph
# urinalysi
# urinari
# urinari_calculus
# urinari_incontin
# urinari_infect_in_children
# urinari_tract
# urinari_tract_infect
# urinari_tract_infect_in_children
# urinari_urgenc
# urin_burn
# urin_difficulti
# urin_pain
# urin
# urin_blood
# urin_hemoglobin
# urin_infect_in_children
# urin_ph
# urod
# urod_defici
# urogastron
# urogenit
# urographi
# urolithiasi
# urolog_surgeon
# urologist
# uroporphyrinogen_decarboxylas
# uroporphyrinogen_decarboxylas_defici
# urothelium
# urticaria
# urticaria_pigmentosa
# us_depart_of_agricultur
# usda
# usfda
# usher_syndrom
# usp
# usph_unit_state_public_health_servic
# ut_dict
# uterin_bleed
# uterin_cancer
# uterin_contract
# uterin_fibroid
# uterin_fornix
# uterin_line
# uterin_retrovers
# uterin_ruptur
# uterin_tube
# uteroglobin
# uterus
# uterus_cancer
# uterus_contract_of_the
# uterus_prolaps
# uterus_tip
# uti
# uti_in_children
# util
# uv_radiat
# uvea
# uveiti
# uvula
# uvul
# uvulopalatopharyngoplasti
# v_cholera_genom
# vaccin
# vaccin_anthrax
# vaccin_chickenpox
# vaccin_children_s
# vaccin_dpt
# vaccin_dt
# vaccin_dtap
# vaccin_german_measl
# vaccin_h_flu
# vaccin_haemophilus_influenza_type_b_hib
# vaccin_hepat_a
# vaccin_hepat_b
# vaccin_hib
# vaccin_infecti_hepat
# vaccin_measl
# vaccin_mump
# vaccin_pneumococc_pneumonia
# vaccin_polio
# vaccin_rubella
# vaccin_td
# vaccin_varicella
# vaccin_yellow_fever
# vaccin_flu
# vaccin_german_measl
# vaccin_inactiv_polio
# vaccin_influenza
# vaccin_kill_polio
# vaccin_live_polio
# vaccin_meningococc
# vaccin_oral_polio
# vaccin_rubella
# vaccin_sabin
# vaccin_sabin_polio
# vaccin_salk
# vaccin_induc_immun_thrombot_thrombocytopenia
# vaccin
# vaccinia
# vaccinia_advers_reaction
# vaccinia_gangrenosa
# vaccinia_immun_globulin
# vaccinia_kerat
# vaccinia_necrosum
# vaccinia_congenit
# vaccinia_dissemin
# vaccinia_fetal
# vaccinia_progress
# vacterl_associ
# vad
# vagina
# vagina_septat
# vagin_birth_after_cesarian_section
# vagin_contracept_spong
# vagin_discharg
# vagin_fornix
# vagin_hysterectomi
# vagin_infect_bacteri
# vagin_introitus
# vagin_membran
# vagin_open
# vagin_spermicid
# vagin_vestibul
# vagin_yeast_infect
# vaginismus
# vagin
# vagin_atroph
# vagin_yeast
# vaginoscopi
# vaginosi_bacteri
# vagus_nerv
# val
# valetudinarian
# valga
# valgum
# valgus
# valin
# vallecula
# valley_fever
# valsalva
# valsalva_maneuv
# valsalva_antonio_maria
# valu_daili
# valv_aortic
# valv_bicuspid
# valv_mitral
# valv_pulmonari
# valv_spitz_holter
# valv_tricuspid
# valv_heart
# vampir_children
# van_der_woud_syndrom
# vancomycin_resist_enterococci_vre
# vanish_bone_syndrom
# vanish_lung_syndrom
# vanish_twin
# vape
# vaqta
# vara
# varco
# varco_richard_l
# variant_angina
# variant_creutzfeldt_jakob_diseas
# variat_observ
# varicella_chickenpox
# varicella_immun
# varicella_rash
# varicella_vaccin
# varicocel
# varicos_vein
# varicos_vein
# varicos
# variola
# variol
# varix
# varum
# varus
# vas_deferen
# vasa_previa
# vascular
# vascular_bed
# vascular_dementia
# vascular_endotheli_growth_factor_vegf
# vascular_headach
# vascular_hemophilia
# vascul
# vascul_allerg
# vascul_retin
# vasectomi
# vasoconstrict
# vasodepressor_syncop
# vasodil
# vasodil
# vasomotor
# vasomotor_rhiniti
# vasopressin
# vasovag_attack
# vasovag_reaction
# vasovag_syncop
# vater_associ
# vater_ampulla_of
# vater_papilla_of
# vbac
# vcjd
# vcu
# vcug
# vdrl_test
# vector
# vector_clone
# vectrin
# vegf
# vein
# vein_of_galen_aneurysm
# vein_brachial
# vein_central_retin
# vein_extern_jugular
# vein_femor
# vein_great_saphen
# vein_hepat
# vein_inferior_vena_cava
# vein_intern_jugular
# vein_jugular
# vein_larg_saphen
# vein_mesenter
# vein_portal
# vein_pulmonari
# vein_saphen
# vein_small_saphen
# vein_splenic
# vein_superior_vena_cava
# vein_varicos
# vein_ophthalm
# veisalgia
# velament_insert_of_umbil_cord
# velocardiofaci_syndrom
# velpeau_hernia
# velvet_ant_sting
# vena_cava
# vena_cava_syndrom_superior
# vena_cava_inferior
# vena_cava_superior
# vener
# vener_diseas
# vener_diseas_research_laboratori_test
# vener_wart
# venin
# venipunctur
# venom
# venom_scorpion
# venom
# venous_aneurysm
# venous_cathet_central
# venous_catheter
# venous_claudic
# venous_line_central
# ventil
# ventil_mechan
# ventil_posit_pressur
# ventil
# ventral
# ventricl
# ventricl_brain
# ventricl_cerebr
# ventricl_fourth
# ventricl_heart
# ventricl_later
# ventricl_leav
# ventricl_right
# ventricl_third
# ventricl
# ventricular
# ventricular_arrhythmia
# ventricular_assist_devic
# ventricular_beat_prematur
# ventricular_fibril
# ventricular_septal_defect_vsd
# ventricular_septum
# ventricular_tachycardia
# ventriculopleur_shunt
# venul
# ver
# verbal_child_abus
# vernix
# vernix_caseosa
# verruca
# version
# vertebra
# vertebra_first_cervic
# vertebra_promin
# vertebra_second_cervic
# vertebra_slip
# vertebra
# vertebra_cervic
# vertebra_coccyg
# vertebra_lumbar
# vertebra_sacral
# vertebra_thorac
# vertebr_arch
# vertebr_arteri
# vertebr_column
# vertebr_compress_fractur
# vertebr_rib
# vertebroplasti
# vertex
# vertic
# vertic_transmiss
# vertigo
# vertigo_benign_paroxysm_posit_bppv
# vertigo_recurr_aural
# veri_low_calori_diet_vlcd
# ves_voluntari_euthanasia_societi
# vesic
# vesic
# vesic
# vesicatori
# vesicl
# vesicl_semin
# vesicl
# vesicoenter
# vesicointestin
# vesicular
# vesicular_rickettsiosi
# vesicul
# vesiculographi
# vessel
# vessel_affer
# vessel_effer
# vestibular
# vestibular_apparatus
# vestibular_disord
# vestibular_neuron
# vestibular_system
# vestibul
# vestibul_of_the_ear
# vestibul_vagin
# vestibulocochlear_nerv
# vestigi
# veterinari_medicin
# vhf
# vhl
# viabl
# vibramycin
# vibrat_white_finger
# vibrio
# vibrio_cholera
# vibrio_cholera_genom
# vibrio_vulnificus
# vibrotactil_aid
# video_assist_resect
# video_assist_surgeri
# vidian_neuralgia
# vig
# villi
# villus
# villus_intestin
# vinca_alkaloid
# vincent_angina
# vincent_gingiv
# vincent_infect
# vincent_stomat
# vinyl_chlorid
# viral
# viral_enceph
# viral_hemorrhag_fever
# viral_hepat
# viral_infect
# viral_myocard
# viral_particl
# viremia
# virgin_membran
# viril
# virion
# virolog
# virtual_colonoscopi
# virul
# virul
# virus
# virus_attenu
# virus_coxsacki
# virus_ebola
# virus_human_immunodefici_hiv
# virus_human_lymphotrop_type_iii
# virus_human_papilloma
# virus_jc
# virus_lymphadenopathi
# virus_lymphadenopathi_associ
# virus_marburg
# virus_negat_strand_rna
# virus_nipah
# virus_posit_strand_rna
# virus_pox
# virus_respiratori_syncyti
# virus_xenotrop
# virus
# viscera
# viscer
# viscer_leishmaniasi
# viscer_pericardium
# viscus
# vision_therapi
# vision_binocular
# vision_blur
# vision_central
# vision_low
# vision_macular
# vision_peripher
# vision_tubular
# vision_tunnel
# visual_acuiti
# visual_acuiti_test
# visual_contrast_sensit
# visual_evok_respons
# visual_field
# visual_field_test
# visual_nerv_pathway
# visual_pathway_glioma
# visual_receptor
# vital
# vital_bodili_function
# vitamin_a
# vitamin_a_defici
# vitamin_b_niacin
# vitamin_b_nicotin_acid
# vitamin_b_pantothen_acid
# vitamin_b
# vitamin_b_defici_infantil
# vitamin_b
# vitamin_b_respons_methylmalonicaciduria
# vitamin_b
# vitamin_b
# vitamin_b
# vitamin_b
# vitamin_b
# vitamin_c
# vitamin_d
# vitamin_d_requir
# vitamin_d
# vitamin_e
# vitamin_k
# vitamin_o
# vitamin_p
# vitamin_q
# vitamin_requir_infant
# vitamin_therapi
# vitamin
# vitiligo
# vitrectomi
# vitreous
# vitreous_type_stickler_syndrom
# vitreous_type_stickler_syndrom
# vlcad_defici
# vocal_cord
# vocal_cord_paralysi
# vocal_cord_fals
# vocal_tremor
# vohwinkel_syndrom
# voic_box
# voic_disord
# void
# void_cystourethrogram
# void_cystourethrographi
# volar
# volum_stroke
# voluntari
# voluntari_euthanasia_societi_ves
# volvulus
# vomer
# vomit
# vomit_in_pregnanc_excess
# vomit_of_pregnanc_pernici
# vomitus
# von_hippel_lindau_syndrom
# von_recklinghausen_diseas
# von_willebrand_diseas
# voyeur
# vrolik_s_diseas
# vsd
# vulnerari
# vulva
# vulva_cancer
# vulvar
# vulvar_cancer
# vulvar_pain_chronic
# vulvar_vestibul
# vulviti
# vulviti_yeast
# vulvodynia_essenti
# vwm
# waardenburg_syndrom
# waardenburg_petrus_johann
# wagner_syndrom
# wagner_s_syndrom
# waldenstrom_macroglobulinemia
# walker_babi
# walk_pneumonia
# walley
# walley
# wambl
# warbl
# warburg_apparatus
# warburg_s_yellow_enzym
# warfarin
# warfarin_teratogen_of
# warshaw
# warshaw_joseph
# wart
# wart_genit
# wart_vener
# wart_plantar
# wasp_sting
# wast
# watch_wait
# water
# water_blister
# water_channel
# water_hammer_puls
# water_intox
# water_on_the_brain
# water_pore
# water_requir_infant
# water_retent
# waterborn_bacteri_diseas
# watermelon
# watermelon_stomach
# watson
# watson_jam
# wax_dip
# wax_ear
# wbc
# wbs
# wdwn
# weasand
# weaver_syndrom
# weaver_s_bottom
# weaver_smith_syndrom
# wegen_s_granulomatosi
# wegen_s_vascul
# weigh_hydrostat
# weigh_underwat
# weight_loss
# weight_watcher
# weil_syndrom
# wellcovorin
# wellen_s_syndrom
# welt
# werdnig_hoffman_diseas_sma
# werewolf_syndrom
# werner_syndrom
# werner_his_diseas
# wesand
# wesil
# west_nile_enceph
# west_nile_fever
# west_nile_virus
# west_syndrom
# western_blot
# western_medicin
# wet_brain
# wet_lung
# wet_market
# wezand
# wf
# wfs
# wharton_s_jelli
# wheal
# wheat_weevil
# wheezer
# wheez
# whi
# whiplash_injuri
# whippl_diseas
# whippl_procedur
# whipworm
# white_blood_cell
# white_blood_cell_count
# white_cell_differenti_autom
# white_coat_hypertens
# white_matter
# white_phosphorus
# white_spot_on_the_nail
# white_subungu_onychomycosi_proxim
# white_coat_hypertens_white_coat_hypertens
# white_foot_mous
# whitehead
# whitmor_s_diseas
# whitmor_jewett_stag_system
# who_world_health_organ
# whole_arm_transloc
# whoop_cough
# whs
# wiedemann_beckwith_syndrom
# wildervanck_syndrom
# wilkin_lawson
# will_live
# willebrand_juergen_diseas
# william_dobell
# william_syndrom
# willi_circl_of
# wilm_tumor
# wilson_diseas
# wimmin
# wind_chill
# window_round
# windpip
# wing_bone
# winter_depress
# wisdom_teeth_tooth
# wisdom_tooth
# witch_s_milk
# withdraw_symptom
# withdraw_peni
# witkop_syndrom
# wm
# wnl
# wolf_hirschhorn_syndrom
# wolff_parkinson_white_syndrom
# wolfram_syndrom
# wolframin
# wolhynia_fever
# womb
# womb_cancer
# women_s_health_initi
# women_s_hospit
# womyn
# word_blind
# word_deaf
# wordprocessor_s_cramp
# work_memori
# world_health_organ
# wormwood
# wpw_syndrom
# wrinkl_retin
# wrist
# writer_s_cramp
# wri_neck
# wt
# wuhan_coronavirus
# wymin
# wymmin
# x_in_genet
# x_chromosom
# x_chromosom_inactiv
# x_inactiv
# x_factor
# x_link
# x_link_juvenil_retinoschisi
# x_link_retinoschisi
# x_ray
# x_ray_crystallographi
# x_ray_ap
# x_ray_later
# x_ray_pa
# x_ray_dure_pregnanc
# xanax
# xanth_prefix
# xanthelasma
# xanthelasma_xanthoma
# xanthin
# xanthinuria
# xanthoma
# xanthoma_tendinosum
# xanthoma_tuberosum
# xanthoma_diabet
# xanthoma_disseminatum
# xanthoma_erupt
# xanthoma_planar
# xanthomatosi
# xanthopsia
# xanthosi
# xen_prefix
# xeno_prefix
# xenoantigen
# xenobiot
# xenograft
# xenotransplant
# xenotrop_virus
# xeric
# xero
# xeroderma
# xeroderma_pigmentosum
# xerogram
# xeromammographi
# xerophagia
# xerophthalmia
# xeroradiograph
# xeroradiographi
# xerosi
# xerostomia
# xiphoid_process
# xp
# xrt
# xtc
# xuezhikang
# xx
# xx_gonad_dysgenesi_with_sensorineur_deaf
# xx_male_syndrom
# xxx_syndrom
# xxxx_syndrom
# xxxxx_syndrom
# xxi
# xy
# xylitol
# xyy
# xyy_syndrom
# y_in_chemistri
# y_in_genet
# y_chromatin
# y_chromosom
# y_chromosom_infertil
# y_chromosom_sex_determin_region
# y_map
# y_sex_determin_region
# y_linkag
# y_link
# y_link_gene
# y_link_inherit
# y_pesti
# yac
# yag_laser_surgeri
# yama
# yard
# yawn
# yawn
# yaw
# yd
# yeast
# yeast_artifici_chromosom_yac
# yeast_diaper_rash
# yeast_genom
# yeast_infect
# yeast_rash
# yeast_syndrom
# yeast_vagin
# yeast_vulviti
# yellow_enzym_warburg_s
# yellow_enzym
# yellow_fever
# yellow_fever_vaccin
# yellow_jack
# yellow_jacket_sting
# yerba_mate
# yersinia
# yersinia_enterocolitica
# yersinia_pesti
# yersinia_pesti_genom
# yersiniosi
# yoga
# yogurt
# yolk_sac
# yolk_stalk
# youth
# youth_violenc
# yttrium
# yttrium_y_ibritumomab_tiuxetan
# z_chromosom
# zap
# zebra
# zeitgeb
# zellweg_syndrom
# zenker_diverticulum
# zenker_s_diverticulum
# zhitai
# zhong_wei_chen
# zidovudin
# zift
# zika_virus
# zinc
# zinc_acet
# zinc_defici
# zinc_defici_dermat_and_diarrhea
# zinc_excess
# zinc_finger
# zinc_finger_protein
# zinc_ointment
# zinc_oxid
# zinc_sulfat
# zinc_finger_protein
# zinsser_diseas
# zip_code_protein
# znf
# zoll
# zoll_paul_m
# zolling_ellison_syndrom
# zolmitriptan
# zomig
# zona
# zona_pellucida
# zone_diet
# zoonosi
# zoonot
# zoonot_diseas
# zoonot_transfer
# zooparasit
# zoophilia
# zoophobia
# zovirax
# zygoma
# zygomat_arch
# zygomat_bone
# zygomycosi
# zygot
# zygot_intrafallopian_transfer_zift
# zygot_lethal_gene

# %% [markdown]
# ## Data pre-processing

# %%
def lemmatize_stemming(text):
    # 把字詞幹化
    stemmer = SnowballStemmer('english')
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
def preprocess(text):
    docu_tmp = []
    documents_lemma = []
    result = [] 
    stop_word = ['ul', 'id', 'sub']
    for token in gensim.utils.simple_preprocess(text, min_len=min_len, max_len=35):  #tokenize
        docu_tmp.append(lemmatize_stemming(token))
    documents_lemma.append(' '.join(docu_tmp))

    text_token = tk.tokenize(documents_lemma[0].split())
    for token in text_token:
        if token in MedTerm_token and token not in gensim.parsing.preprocessing.STOPWORDS and token not in stop_word:
            result.append(token)
    return result

# %%
# 分三個年份
processed_docs_1 = df_1['summary'].map(preprocess)
processed_docs_2 = df_2['summary'].map(preprocess)
processed_docs_3 = df_3['summary'].map(preprocess)

# %%
# 不分年分
processed_docs = documents_merge['CONTENT'].map(preprocess)

# %% [markdown]
# ## Bag of Words on the Data set

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
for k, v in dictionary.iteritems():
    print(v)
# Out:
# absorb
# absorpt
# advers_reaction
# allerg_reaction
# antineoplast
# blood
# condit
# diseas
# drug_resist
# enzym
# gastrointestin_tract
# medic
# metabol
# oral
# parenter
# patient
# side_effect
# subject
# substanc
# therapeut
# therapi
# toxic
# acn
# adenovirus
# anti
# arteri
# assay
# astrocytoma
# bladder
# bp
# brain_tumor
# breast
# cancer
# carcinoma
# carotid
# cdna
# cell
# cervic
# cisplatin
# colorect
# delet
# dna
# dna_sequenc
# essenti
# exogen
# express
# g
# gene
# head_and_neck_cancer
# hepat_arteri
# hepatocarcinoma
# herp
# infus
# intraperiton
# late
# leukemia
# lipid
# lung
# lymphoma
# major
# melanoma
# membran
# mesothelioma
# mg
# neoplast
# neuroblastoma
# neurolog
# non_small_cell_lung_cancer
# nucleic_acid
# osteosarcoma
# ovarian
# ovarian_cancer
# p
# pancreat_cancer
# pharmacolog
# plasmid
# polypeptid
# promot
# prostat
# protein
# rang
# recombin
# recombin_dna_technolog
# recur
# regimen
# renal_cancer
# repeat
# retinoblastoma
# retrovirus
# sarcoma
# sequenc
# small_cell_lung_cancer
# tissu
# topic
# tumor
# vaccinia
# vector
# viral
# virus
# anthracyclin
# biopsi
# develop
# gastrointestin
# host
# neck
# object
# radioact
# scan
# specif
# stage
# synthesi
# test
# util
# version
# access
# acromegali
# american_type_cultur_collect_atcc
# amino_acid
# antibodi
# antigen
# associ
# atherosclerosi
# b_cell
# benign_prostat_hyperplasia
# bone_cancer
# breast_cancer
# cervic_cancer
# colorect_cancer
# cultur
# d
# diarrhea
# genom
# gigant
# h
# hybridoma
# immun
# immunoglobulin
# insert
# insulin
# intestin
# isol
# l
# ligand
# lung_cancer
# malign
# microvascular
# monoclon_antibodi
# myeloma
# nucleotid
# peptid
# prostat_cancer
# psoriasi
# receptor
# restenosi
# smooth_muscl
# synovi_sarcoma
# transgen
# vessel
# allel
# analysi
# androgen
# basal_cell
# bph
# chromosom
# contrast
# epithelium
# famili
# fluoresc_in_situ_hybrid
# gland
# homolog
# immunolog
# in_situ
# intraepitheli
# linkag
# marker
# molecul
# monoclon
# mrna
# neoplasia
# pin
# polyclon
# prognosi
# prostat_gland
# psa
# stag
# stem_cell
# upregul
# xenograft
# alpha
# angiogenesi
# pathogen
# rnai
# sirna
# vegf
# aggress
# biallel
# diagnosi
# genet
# hybrid
# oligonucleotid_probe
# onset
# polymorph
# process
# regulatori_region
# conjunct
# cytotox
# indic
# nf
# acquir
# affin
# agonist
# alopecia
# amin
# antiandrogen
# atom
# bald
# bromin
# dot
# exacerb
# hirsut
# hydrocarbon
# hydrogen
# iodin
# male
# methyl
# mm
# nitrogen
# nucleus
# oxygen
# polycyst_ovarian_syndrom
# precoci_puberti
# r
# salt
# seborrhea
# skin
# steroid
# syndrom
# clinic
# cpg
# cpg_island
# differenti
# dinucleotid
# guanin
# probe
# restrict_enzym
# sensit
# analog
# chlorid
# cor
# glycin
# iodid
# os
# p_o
# parent
# water
# ab
# acut_lymphoblast_leukemia
# angiotensin_convert_enzym
# arthriti
# attenu
# autoimmun
# biochem
# biotin
# bmp
# bovin
# carbohydr
# cardiac
# cardiovascular_diseas
# chronic
# clone_cell
# collagen
# connect_tissu
# dermatofibroma
# desmoplasia
# desmoplast
# diabet
# diabet_nephropathi
# dissoci
# domain
# elisa
# endogen
# endotheli
# epitheli
# epitop
# eukaryot
# extracellular
# eye
# fibroblast
# fibrosarcoma
# g_protein
# glioma
# heart
# heart_failur
# histolog
# hyperglycemia
# hypertens
# idiopath_pulmonari_fibrosi
# in_vitro
# in_vivo
# inflamm
# inflammatori_respons
# kidney
# liver
# mab
# macular_degener
# metastas
# mi
# myocardi_infarct
# nephrectomi
# obes
# obstruct
# ocular
# oper
# organ
# ortholog
# osteoarthr
# pancreat
# phage
# plasma
# porcin
# prokaryot
# pulmonari
# radioimmunoassay
# radioisotop
# replic
# residu
# retinopathi
# rhabdomyosarcoma
# scleroderma
# strain
# tgf
# transcript
# transplant
# trauma
# unilater
# uret
# adjac
# exon
# express_sequenc_tag_est
# intron
# librari
# peripher
# rna
# symptom
# adhes
# adipos
# age
# alcohol
# arginin
# asp
# aspart_acid
# bacteri
# bio
# bioactiv
# bone
# bone_marrow
# calcium
# cartilag
# cation
# cell_therapi
# chemokin
# chondroitin_sulfat
# colon
# coloni_stimul_factor
# connexin
# csf
# cytokin
# dendrit_cell
# elastin
# enter
# event
# exit
# fibrin
# fibulin
# gene_product
# genotyp
# gli
# glycoprotein
# graft
# granulocyt
# hematopoiet
# heparin
# hormon
# hyaluron_acid
# ile
# immun_activ
# immun_respons
# implant
# injur
# integrin
# interferon
# interleukin
# intern
# lead
# locomot
# lymph
# macrophag
# muscl
# neural
# neurotransmitt
# oligonucleotid
# oligopeptid
# osteoblast
# pam
# particip
# ph
# phenotyp
# poli
# precursor
# progeni
# progress
# regener
# resid
# resist
# scaffold
# ser
# signal_transduct
# t_cell
# temperatur
# tempor
# tendon
# thrombospondin
# tyr
# vaccin
# vascular_endotheli_growth_factor_vegf
# antisens
# egfr
# aberr
# albumin
# amniot_fluid
# autoimmun_diseas
# biotechnolog
# cerebrospin_fluid
# chronic_myelogen_leukemia
# cranial
# cryptic
# gene_express
# genom_structur
# hapten
# humor
# igg
# immun_system
# immunotherapi
# lymphocyt
# myeloprolif
# open_read_frame
# phosphat
# polycythemia
# polycythemia_vera_pv
# proteom
# pv
# quantit
# read_frame
# remiss
# ribosom
# saliva
# serum
# sodium
# strip
# synovi_fluid
# testi
# translat
# tube
# urin
# viral_infect
# a_t
# acut
# acut_myelogen_leukemia
# acut_myeloid_leukemia
# adenocarcinoma
# adenoma
# adren_gland
# adult_t_cell_leukemia_lymphoma
# aml
# angiosarcoma
# axi
# basal_cell_carcinoma
# benign
# brain_stem
# carcinoma_basal_cell
# cd
# central
# cervix
# chondrosarcoma
# chronic_lymphocyt_leukemia
# cutan
# cystadenoma
# dermatofibrosarcoma_protuberan
# diphtheria
# dt
# e_f
# egf
# endocrin
# endometrium
# er
# esophag
# ewe_sarcoma
# fallopian_tube
# g_csf
# gvhd
# gynecolog
# hepatocellular_carcinoma
# htlv
# il
# intraocular_melanoma
# laryng
# leiomyoma
# liposarcoma
# lymphoma_burkitt
# lymphoma_non_hodgkin
# malign_melanoma
# medulloblastoma
# meningioma
# merkel_cell_carcinoma
# metastasi
# mhc
# multipl_myeloma
# mutant
# mutat
# nasal
# peni
# pituitari_adenoma
# primari
# refractori
# relaps
# renal
# renal_cell_carcinoma
# round
# small_intestin
# squamous_cell_carcinoma
# stomach
# t
# t_cell_leukemia
# t_cell_lymphoma
# tabl
# teratoma
# thyroid
# tnf
# toxin
# urethra
# vagina
# vascular
# vulva
# clinic_trial
# colon_cancer
# encapsul
# environ
# hepatotox
# hsp
# lethal
# neuropathi
# neutropenia
# peg
# salin
# wt
# fgfr
# hemi
# pat
# tyrosin
# cm
# infect
# prodrug
# prolif
# topoisomeras
# abnorm
# antibacteri
# anxieti
# benzodiazepin
# depress
# diuret
# dysphoria
# hypotens
# optic
# osteoporosi
# pain
# panic
# patholog
# phobia
# psychiatr
# stress
# sulfonamid
# anesthesia
# anesthet
# bicarbon
# extens
# post
# adjuv_therapi
# cluster
# alkyl_group
# cf
# chf
# generic
# neoplasm
# ra
# bladder_cancer
# cancer_brain
# cancer_lung
# cancer_ovari
# cancer_prostat
# esophag_cancer
# gastric_cancer
# kidney_cancer
# larg_bowel
# mastocytoma
# urinari
# cll
# cml
# compress
# dextros
# endometri_cancer
# gastric
# lactos
# pi
# rectal_cancer
# tablet
# talc
# unresect
# adjuv
# append
# asthma
# chronic_obstruct_pulmonari_diseas
# crohn_s_diseas
# etiolog
# gastrointestin_stromal_tumor
# hepat
# i_q
# inhal
# lupus
# mast_cell
# mastocytosi
# multipl_sclerosi
# nephriti
# oncogen
# oxi
# primari_tumor
# pyrimidin
# rheumatoid_arthriti
# subcutan
# a_c
# apoptosi
# bridg
# antagonist
# autolog
# cancer_antigen
# cell_b
# cryopreserv
# death
# gamma_ray
# icd
# incub
# irradi
# microb
# photodynam_therapi
# physiolog
# potassium
# puls
# reagent
# ar
# para
# adi
# amelior
# brain_cancer
# cystein
# glioblastoma_multiform
# hepatoma
# histidin
# leukemia_acut_myeloid
# lysin
# mycoplasma
# pneumonia
# stomach_cancer
# testicular_cancer
# uterin_cancer
# keton
# proteas
# serin
# adeno
# cancer_bone
# cancer_ovarian
# cancer_rectal
# cdc
# clone
# coxsackievirus
# cytomegalovirus_cmv
# echovirus
# ependymoma
# epidermoid_carcinoma
# gene_suicid
# gfp
# influenza
# measl
# mump
# myxoma
# oligodendroglioma
# resect
# schwannoma
# tumor_suppressor_gene
# vesicular
# accessori
# acet
# aerosol
# al
# anion
# antibiot
# antibodi_depend_cell_mediat_cytotox
# antimetabolit
# arsenic
# bacteriostat
# bile_acid
# brain
# cancer_cervic
# cancer_gastric
# cancer_kidney
# capsul
# carbon_dioxid
# circul
# complic
# corn
# corpor
# corticosteroid
# crc
# di
# donor
# e_coli
# ebv
# effect_dose
# egg
# ep
# epstein_barr_virus
# et
# extrem
# fatti_acid
# filler
# fluorid
# gallium
# glucos
# granul
# immunosuppress
# impact
# intracrani
# intraventricular
# iron
# isotop
# laboratori
# lactat
# lubric
# magnesium
# mono
# nph
# orf
# ovari
# penetr
# peptidomimet
# pigment
# proc
# prophylact
# proxim
# recipi
# scale
# silver
# sspe
# th
# thallium
# trigger
# triglycerid
# uterus
# vagin
# yeast
# yttrium
# zinc
# zinc_oxid
# chemotherapi
# nausea
# vomit
# minor
# cea
# alzheim_s_diseas
# atop_dermat
# cardiomegali
# circulatori
# copd
# hcv
# hiv
# impot
# respiratori
# skeleton
# balanc
# bone_densiti
# cytoplasm
# gray
# health
# homozyg
# incid
# longev
# lys
# mirna
# motor
# phosphoryl
# pox_virus
# shrna

# %%
print(dictionary)
# Out:
# Dictionary(800 unique tokens: ['absorb', 'absorpt', 'advers_reaction', 'allerg_reaction', 'antineoplast']...)

# %%
dictionary_1 = gensim.corpora.Dictionary(processed_docs_1)
dictionary_2 = gensim.corpora.Dictionary(processed_docs_2)
dictionary_3 = gensim.corpora.Dictionary(processed_docs_3)

# %%
print(dictionary_1)
print(dictionary_2)
print(dictionary_3)
# Out:
# Dictionary(255 unique tokens: ['absorb', 'absorpt', 'advers_reaction', 'allerg_reaction', 'antineoplast']...)
# Dictionary(494 unique tokens: ['ab', 'access', 'acut_lymphoblast_leukemia', 'affin', 'amino_acid']...)
# Dictionary(456 unique tokens: ['acut_myelogen_leukemia', 'aml', 'breast_cancer', 'calcium', 'cancer']...)

# %%
for k, v in dictionary_1.iteritems():
    print(v)
# Out:
# absorb
# absorpt
# advers_reaction
# allerg_reaction
# antineoplast
# blood
# condit
# diseas
# drug_resist
# enzym
# factor
# gastrointestin_tract
# medic
# metabol
# oral
# parenter
# patient
# side_effect
# subject
# substanc
# therapeut
# therapi
# toxic
# acn
# adenovirus
# anti
# arteri
# assay
# astrocytoma
# bladder
# bp
# brain_tumor
# breast
# cancer
# carcinoma
# carotid
# cdna
# cell
# cervic
# cisplatin
# colorect
# delet
# dna
# dna_sequenc
# essenti
# exogen
# express
# gene
# head_and_neck_cancer
# hepat_arteri
# hepatocarcinoma
# herp
# infus
# intraperiton
# late
# leukemia
# lipid
# lung
# lymphoma
# major
# melanoma
# membran
# mesothelioma
# mg
# neoplast
# neuroblastoma
# neurolog
# non_small_cell_lung_cancer
# nucleic_acid
# osteosarcoma
# ovarian
# ovarian_cancer
# pancreat_cancer
# pharmacolog
# plasmid
# polypeptid
# promot
# prostat
# protein
# rang
# recombin
# recombin_dna_technolog
# recur
# regimen
# renal_cancer
# repeat
# retinoblastoma
# retrovirus
# sarcoma
# sequenc
# small_cell_lung_cancer
# tissu
# topic
# tumor
# tumor_suppressor_gene
# vaccinia
# vector
# viral
# virus
# wilm_tumor
# anthracyclin
# biopsi
# develop
# gastrointestin
# host
# neck
# object
# plan
# radioact
# scan
# specif
# stage
# synthesi
# test
# util
# version
# access
# acromegali
# american_type_cultur_collect_atcc
# amino_acid
# antibodi
# antigen
# associ
# atherosclerosi
# benign_prostat_hyperplasia
# bone_cancer
# breast_cancer
# cervic_cancer
# colorect_cancer
# cultur
# diarrhea
# genom
# gigant
# hybridoma
# immun
# immunoglobulin
# insert
# insulin
# intestin
# isol
# ligand
# lung_cancer
# malign
# microvascular
# monoclon_antibodi
# myeloma
# nucleotid
# peptid
# prostat_cancer
# psoriasi
# receptor
# restenosi
# smooth_muscl
# synovi_sarcoma
# transgen
# vessel
# allel
# analysi
# androgen
# basal_cell
# bph
# chromosom
# contrast
# epithelium
# famili
# fluoresc_in_situ_hybrid
# gland
# homolog
# immunolog
# in_situ
# intraepitheli
# linkag
# marker
# molecul
# monoclon
# mrna
# neoplasia
# pin
# polyclon
# prognosi
# prostat_gland
# psa
# stag
# stem_cell
# upregul
# xenograft
# alpha
# angiogenesi
# pathogen
# rnai
# sirna
# vegf
# aggress
# biallel
# diagnosi
# genet
# hybrid
# oligonucleotid_probe
# onset
# polymorph
# process
# regulatori_region
# conjunct
# cytotox
# indic
# nf
# acquir
# affin
# agonist
# alopecia
# amin
# antiandrogen
# atom
# bald
# bromin
# dot
# exacerb
# hirsut
# hydrocarbon
# hydrogen
# iodin
# link
# male
# methyl
# mm
# nitrogen
# nucleus
# oxygen
# polycyst_ovarian_syndrom
# precoci_puberti
# salt
# seborrhea
# skin
# steroid
# syndrom
# clinic
# cpg
# cpg_island
# cytosin
# differenti
# dinucleotid
# guanin
# probe
# restrict_enzym
# sensit
# analog
# chlorid
# cor
# glycin
# iodid
# os
# parent
# water

# %%
for k, v in dictionary_2.iteritems():
    print(v)
# Out:
# ab
# access
# acut_lymphoblast_leukemia
# affin
# amino_acid
# analysi
# angiotensin_convert_enzym
# antibodi
# antigen
# arthriti
# assay
# associ
# attenu
# autoimmun
# biochem
# biotin
# bmp
# bovin
# breast
# breast_cancer
# cancer
# carbohydr
# carcinoma
# cardiac
# cardiovascular_diseas
# cell
# cell_receptor
# cell_stem
# chronic
# clone_cell
# collagen
# colorect
# condit
# connect_tissu
# cultur
# cytotox
# dermatofibroma
# desmoplasia
# desmoplast
# develop
# diabet
# diabet_nephropathi
# differenti
# dissoci
# domain
# elisa
# endogen
# endotheli
# enzym
# epitheli
# epitop
# eukaryot
# express
# extracellular
# eye
# factor
# famili
# fibroblast
# fibrosarcoma
# gastrointestin
# gene
# genet
# glioma
# heart
# heart_failur
# histolog
# host
# hybridoma
# hyperglycemia
# hypertens
# idiopath_pulmonari_fibrosi
# immun
# immunoglobulin
# in_vitro
# in_vivo
# inflamm
# inflammatori_respons
# kidney
# link
# lipid
# liver
# lung
# mab
# macular_degener
# membran
# metastas
# mi
# molecul
# monoclon_antibodi
# myocardi_infarct
# nephrectomi
# nucleic_acid
# nucleotid
# obes
# obstruct
# ocular
# oper
# organ
# ortholog
# osteoarthr
# ovarian
# pancreat
# patient
# phage
# plasma
# polyclon
# polypeptid
# porcin
# prokaryot
# prostat
# protein
# pulmonari
# radioimmunoassay
# radioisotop
# recombin
# repeat
# replic
# residu
# retinopathi
# rhabdomyosarcoma
# salt
# scleroderma
# sequenc
# skin
# smooth_muscl
# specif
# strain
# subject
# substanc
# tgf
# therapeut
# tissu
# transcript
# transgen
# transplant
# trauma
# tumor
# unilater
# uret
# vector
# adjac
# biopsi
# blood
# cdna
# diagnosi
# diseas
# dna
# exon
# express_sequenc_tag_est
# indic
# intron
# librari
# object
# onset
# peripher
# probe
# process
# prognosi
# rna
# symptom
# test
# adhes
# adipos
# age
# alcohol
# angiogenesi
# arginin
# asp
# aspart_acid
# bacteri
# bio
# bioactiv
# bone
# bone_marrow
# calcium
# cartilag
# cation
# cell_therapi
# chemokin
# chondroitin_sulfat
# colon
# coloni_stimul_factor
# connexin
# csf
# cytokin
# dendrit_cell
# elastin
# enter
# event
# exit
# fibrin
# fibulin
# gene_product
# genotyp
# gli
# glycin
# glycoprotein
# graft
# granulocyt
# hematopoiet
# heparin
# hormon
# hyaluron_acid
# hydrogen
# ile
# immun_activ
# immun_respons
# implant
# injur
# insert
# integrin
# interferon
# interleukin
# intern
# intestin
# lead
# ligand
# linkag
# locomot
# lymph
# macrophag
# muscl
# neural
# neurotransmitt
# oligonucleotid
# oligopeptid
# osteoblast
# oxygen
# pam
# particip
# pathogen
# peptid
# ph
# phenotyp
# plasmid
# poli
# precursor
# progeni
# progress
# promot
# rang
# receptor
# regener
# resid
# resist
# scaffold
# sensit
# ser
# signal_transduct
# stag
# stage
# stem_cell
# temperatur
# tempor
# tendon
# thrombospondin
# tyr
# vaccin
# vascular_endotheli_growth_factor_vegf
# vegf
# anti
# antisens
# egfr
# mrna
# therapi
# aberr
# albumin
# amniot_fluid
# autoimmun_diseas
# biotechnolog
# cerebrospin_fluid
# chronic_myelogen_leukemia
# cranial
# cryptic
# gene_express
# genom_structur
# hapten
# homolog
# humor
# hybrid
# igg
# immun_system
# immunotherapi
# isol
# lymphocyt
# mm
# monoclon
# myeloprolif
# open_read_frame
# phosphat
# polycythemia
# polycythemia_vera_pv
# prostat_cancer
# proteom
# pv
# quantit
# read_frame
# remiss
# ribosom
# saliva
# serum
# sodium
# strip
# synovi_fluid
# testi
# translat
# tube
# upregul
# urin
# viral_infect
# virus
# acut
# acut_myelogen_leukemia
# acut_myeloid_leukemia
# adenocarcinoma
# adenoma
# adren_gland
# adult_cell_leukemia_lymphoma
# aml
# angiosarcoma
# astrocytoma
# axi
# basal_cell_carcinoma
# benign
# bladder
# brain_stem
# brain_tumor
# carcinoma_basal_cell
# cd
# cell_leukemia
# cell_lymphoma
# central
# cervic
# cervix
# chondrosarcoma
# chronic_lymphocyt_leukemia
# cutan
# cystadenoma
# dermatofibrosarcoma_protuberan
# diphtheria
# dt
# egf
# endocrin
# endometrium
# er
# esophag
# fallopian_tube
# gorlin_syndrom
# gvhd
# gynecolog
# hepatocellular_carcinoma
# hodgkin_diseas
# hormon_growth
# htlv
# il
# insulin
# intraocular_melanoma
# kaposi_sarcoma
# laryng
# leiomyoma
# liposarcoma
# lung_cancer
# lymphoma
# lymphoma_burkitt
# malign
# malign_melanoma
# medulloblastoma
# melanoma
# meningioma
# merkel_cell_carcinoma
# mesothelioma
# metastasi
# mhc
# multipl_myeloma
# mutant
# mutat
# nasal
# natur_killer_cell
# neck
# non_small_cell_lung_cancer
# oral
# osteosarcoma
# ovarian_cancer
# peni
# pituitari_adenoma
# psoriasi
# refractori
# relaps
# renal
# renal_cell_carcinoma
# retinoblastoma
# round
# sarcoma
# sarcoma_ewe
# side_effect
# small_cell_lung_cancer
# small_intestin
# squamous_cell_carcinoma
# stomach
# syndrom
# tabl
# teratoma
# thyroid
# tnf
# toxin
# tripl
# tumor_primari
# urethra
# vagina
# vascular
# vulva
# atom
# methyl
# clinic_trial
# colon_cancer
# encapsul
# environ
# head_and_neck_cancer
# hepatotox
# hsp
# intraperiton
# lethal
# leukemia
# medic
# mg
# neuroblastoma
# neuropathi
# neutropenia
# pancreat_cancer
# peg
# salin
# toxic
# wt
# fgfr
# hemi
# pat
# tyrosin
# cm
# infect
# nitrogen
# os
# prodrug
# prolif
# topoisomeras
# abnorm
# amin
# antibacteri
# anxieti
# benzodiazepin
# cor
# depress
# dimer
# diuret
# dysphoria
# hypotens
# in_situ
# optic
# osteoporosi
# pain
# panic
# patholog
# phobia
# polymorph
# psychiatr
# stress
# sulfonamid
# anesthesia
# anesthet
# bicarbon
# extens
# post
# adjuv_therapi
# cluster
# alkyl_group
# cf
# chf
# generic
# neoplasm
# ra
# bladder_cancer
# cancer_brain
# cancer_lung
# cancer_ovari
# cancer_prostat
# esophag_cancer
# gastric_cancer
# immunolog
# kidney_cancer
# larg_bowel
# mastocytoma
# urinari

# %%
for k, v in dictionary_3.iteritems():
    print(v)
# Out:
# acut_myelogen_leukemia
# aml
# breast_cancer
# calcium
# cancer
# carcinoma
# cervic_cancer
# chronic_myelogen_leukemia
# cll
# cml
# colon_cancer
# compress
# dextros
# endometri_cancer
# gastric
# hepatocellular_carcinoma
# lactos
# lymphocyt
# lymphoma
# melanoma
# methyl
# mg
# non_small_cell_lung_cancer
# object
# ovarian_cancer
# pancreat_cancer
# patient
# phosphat
# pi
# polymorph
# prostat
# rectal_cancer
# refractori
# relaps
# small_cell_lung_cancer
# sodium
# specif
# subject
# tablet
# talc
# thyroid
# tumor
# unresect
# aberr
# adjuv
# alkyl_group
# append
# asthma
# autoimmun
# bone
# cervic
# chronic_obstruct_pulmonari_diseas
# crohn_diseas
# diseas
# etiolog
# gastrointestin_stromal_tumor
# hepat
# hydrogen
# ib
# indic
# inhal
# leukemia
# lung_cancer
# lupus
# mast_cell
# mastocytosi
# metabol
# metastasi
# mm
# multipl_myeloma
# multipl_sclerosi
# mutant
# nephriti
# oncogen
# oral
# osteoarthr
# osteoporosi
# osteosarcoma
# oxi
# parenter
# primari_tumor
# progress
# prostat_cancer
# protein
# pyrimidin
# renal_cancer
# rheumatoid_arthriti
# salt
# subcutan
# symbol
# test
# apoptosi
# bridg
# cell
# nitrogen
# oxygen
# substanc
# therapeut
# therapi
# alcohol
# antagonist
# anthracyclin
# anti
# antibodi
# antigen
# autolog
# cancer_antigen
# cardiac
# cisplatin
# cryopreserv
# cultur
# death
# dendrit_cell
# egfr
# express
# gamma_ray
# genet
# genotyp
# icd
# immun_respons
# immunotherapi
# incub
# irradi
# microb
# pharmacolog
# phenotyp
# photodynam_therapi
# physiolog
# poli
# potassium
# process
# puls
# reagent
# regimen
# stage
# temperatur
# util
# vaccin
# ar
# atom
# para
# synthesi
# acut_myeloid_leukemia
# adi
# amelior
# amino_acid
# arginin
# bladder_cancer
# blood
# brain_cancer
# carbohydr
# colorect_cancer
# cystein
# esophag_cancer
# gastric_cancer
# glioblastoma_multiform
# glioma
# head_and_neck_cancer
# hepatoma
# histidin
# host
# in_vivo
# isol
# kidney_cancer
# leukemia_acut_myeloid
# lysin
# mesothelioma
# molecul
# mycoplasma
# organ
# peg
# ph
# pneumonia
# residu
# sarcoma
# sequenc
# stomach_cancer
# symptom
# tabl
# testicular_cancer
# tyrosin
# uterin_cancer
# vector
# associ
# condit
# abnorm
# chemokin
# cytokin
# immun
# keton
# malign
# proteas
# serin
# adeno
# adenovirus
# astrocytoma
# cancer_bone
# cancer_ovarian
# cancer_rectal
# cdc
# cdna
# clone
# coxsackievirus
# csf
# cytomegalovirus_cmv
# cytosin
# cytotox
# echovirus
# enzym
# ependymoma
# epidermoid_carcinoma
# fibrosarcoma
# gene
# gene_suicid
# gfp
# herp
# in_vitro
# influenza
# infus
# intraperiton
# librari
# liver
# lymphoma_non_hodgkin
# marker
# measl
# medulloblastoma
# meningioma
# mump
# mutat
# myxoma
# neuroblastoma
# nucleic_acid
# oligodendroglioma
# parvovirus
# pituitari_adenoma
# primari
# prodrug
# renal_cell_carcinoma
# replic
# resect
# schwannoma
# serum
# squamous_cell_carcinoma
# transgen
# tumor_suppressor_gene
# vaccinia
# vesicular
# virus
# ab
# access
# accessori
# acet
# aerosol
# affin
# age
# al
# albumin
# analog
# anion
# antibiot
# antibodi_depend_cell_mediat_cytotox
# antimetabolit
# arsenic
# arteri
# assay
# bacteriostat
# bile_acid
# biochem
# brain
# breast
# cancer_cervic
# cancer_gastric
# cancer_kidney
# capsul
# carbon_dioxid
# cation
# chlorid
# circul
# clinic
# coli
# collagen
# colon
# complic
# corn
# corpor
# corticosteroid
# crc
# develop
# di
# dna
# domain
# donor
# ebv
# effect_dose
# egg
# elisa
# ep
# epstein_barr_virus
# essenti
# et
# event
# extrem
# fatti_acid
# filler
# fluorid
# gallium
# glucos
# glycin
# granul
# hormon
# hyaluron_acid
# hybrid
# hybridoma
# il
# immun_system
# immunoglobulin
# immunosuppress
# impact
# implant
# interleukin
# intracrani
# intraventricular
# iodid
# iodin
# iron
# isotop
# laboratori
# lactat
# lead
# link
# lipid
# lubric
# lung
# magnesium
# medic
# mono
# monoclon
# monoclon_antibodi
# nasal
# neck
# nph
# ocular
# oligonucleotid
# oper
# orf
# ovari
# pat
# patholog
# penetr
# peptid
# peptidomimet
# phage
# pigment
# polypeptid
# probe
# proc
# prophylact
# prostat_gland
# proxim
# radioact
# radioisotop
# receptor
# recipi
# rna
# salin
# scale
# scan
# silver
# skin
# sspe
# stem_cell
# th
# thallium
# tissu
# topic
# topoisomeras
# toxic
# toxin
# trigger
# triglycerid
# urinari
# uterus
# vagin
# version
# water
# yeast
# yttrium
# zinc
# zinc_oxid
# central
# chemotherapi
# nausea
# vomit
# dimer
# minor
# adjac
# alpha
# cor
# cd
# cea
# col
# delet
# insert
# angiogenesi
# atop_dermat
# benign
# cardiomegali
# chronic
# circulatori
# copd
# diseas_alzheim
# diseas_autoimmun
# hcv
# hiv
# idiopath_pulmonari_fibrosi
# impot
# infect
# respiratori
# skeleton
# allel
# antisens
# attenu
# balanc
# bone_densiti
# brain_tumor
# cancer_breast
# cancer_colon
# cancer_prostat
# cytoplasm
# endogen
# exogen
# factor
# gray
# health
# homozyg
# incid
# longev
# lys
# mirna
# motor
# mrna
# muscl
# nucleus
# phosphoryl
# post
# pox_virus
# prolif
# promot
# retinoblastoma
# retrovirus
# shrna
# sirna
# translat
# viral

# %%
dictionary_1.filter_extremes(no_below=0, no_above=0.5, keep_n=100000)
dictionary_2.filter_extremes(no_below=0, no_above=0.5, keep_n=100000)
dictionary_3.filter_extremes(no_below=0, no_above=0.5, keep_n=100000)

# %%
print(dictionary_1)
print(dictionary_2)
print(dictionary_3)
# Out:
# Dictionary(249 unique tokens: ['absorb', 'absorpt', 'advers_reaction', 'allerg_reaction', 'antineoplast']...)
# Dictionary(492 unique tokens: ['ab', 'access', 'acut_lymphoblast_leukemia', 'affin', 'amino_acid']...)
# Dictionary(455 unique tokens: ['acut_myelogen_leukemia', 'aml', 'breast_cancer', 'calcium', 'carcinoma']...)

# %% [markdown]
# ## Gensim doc2bow

# %%
bow_corpus_1 = [dictionary_1.doc2bow(doc) for doc in processed_docs_1]
bow_corpus_2 = [dictionary_2.doc2bow(doc) for doc in processed_docs_2]
bow_corpus_3 = [dictionary_3.doc2bow(doc) for doc in processed_docs_3]
# Out:
# C:\Users\Annie\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#processed_docs = documents_merge['TACD'].map(preprocess)

# %%
#processed_docs

# %% [markdown]
# ## Bag of Words on the Data set

# %%
#dictionary = gensim.corpora.Dictionary(processed_docs)
#print(dictionary)

# %%
#dictionary.filter_extremes(no_below=3, no_above=0.5, keep_n=100000)
#print(dictionary)

# %% [markdown]
# ## Gensim doc2bow

# %%
#bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %% [markdown]
# ## Find the optimal number of topics for LDA?

# %%
from gensim.models import CoherenceModel
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.LdaMulticore(corpus, num_topics=num_topics, id2word=dictionary, passes=50, workers=8)
        #model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Can take a long time to run.
model_list_1, coherence_values_1 = compute_coherence_values(dictionary=dictionary_1, corpus=bow_corpus_1, texts=processed_docs_1, start=2, limit=9, step=1)
model_list_2, coherence_values_2 = compute_coherence_values(dictionary=dictionary_2, corpus=bow_corpus_2, texts=processed_docs_2, start=2, limit=9, step=1)
model_list_3, coherence_values_3 = compute_coherence_values(dictionary=dictionary_3, corpus=bow_corpus_3, texts=processed_docs_3, start=2, limit=9, step=1)
# Out:
# C:\Users\Annie\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Show graph
import matplotlib.pyplot as plt
# %matplotlib inline

limit=9; start=2; step=1;
x = range(start, limit, step)
plt.plot(x, coherence_values_1)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

x = range(start, limit, step)
plt.plot(x, coherence_values_2)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

x = range(start, limit, step)
plt.plot(x, coherence_values_3)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()
# Out:
# C:\Users\Annie\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values_1):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4)) #2
    
for m, cv in zip(x, coherence_values_2):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4)) #3

for m, cv in zip(x, coherence_values_3):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4)) #4
# Out:
# Num Topics = 2  has Coherence Value of 0.3964
# Num Topics = 3  has Coherence Value of 0.3954
# Num Topics = 4  has Coherence Value of 0.3795
# Num Topics = 5  has Coherence Value of 0.5786
# Num Topics = 6  has Coherence Value of 0.5685
# Num Topics = 7  has Coherence Value of 0.5368
# Num Topics = 8  has Coherence Value of 0.5969
# Num Topics = 2  has Coherence Value of 0.2588
# Num Topics = 3  has Coherence Value of 0.3213
# Num Topics = 4  has Coherence Value of 0.3663
# Num Topics = 5  has Coherence Value of 0.4545
# Num Topics = 6  has Coherence Value of 0.4114
# Num Topics = 7  has Coherence Value of 0.4397
# Num Topics = 8  has Coherence Value of 0.3816
# Num Topics = 2  has Coherence Value of 0.3784
# Num Topics = 3  has Coherence Value of 0.3623
# Num Topics = 4  has Coherence Value of 0.5067
# Num Topics = 5  has Coherence Value of 0.4119
# Num Topics = 6  has Coherence Value of 0.5109
# Num Topics = 7  has Coherence Value of 0.4134
# Num Topics = 8  has Coherence Value of 0.3933
# C:\Users\Annie\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Select the model and print the topics
from pprint import pprint
optimal_model_1 = model_list_1[3]
model_topics = optimal_model_1.show_topics(formatted=False)
#pprint(optimal_model.print_topics(num_words=10))

optimal_model_2 = model_list_2[3]
model_topics = optimal_model_2.show_topics(formatted=False)
#pprint(optimal_model.print_topics(num_words=10))

optimal_model_3 = model_list_3[-3]
model_topics = optimal_model_3.show_topics(formatted=False)
#pprint(optimal_model.print_topics(num_words=10))
# Out:
# C:\Users\Annie\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## save model

# %%
from gensim.corpora import MmCorpus
if save_model == 1:
    MmCorpus.serialize('patent_1.mm', bow_corpus_1)
    dictionary_1.save('patent_1.dict')
    MmCorpus.serialize('patent_2.mm', bow_corpus_2)
    dictionary_2.save('patent_2.dict')
    MmCorpus.serialize('patent_3.mm', bow_corpus_3)
    dictionary_3.save('patent_3.dict')
    optimal_model_1.save('patent_1.model')
    optimal_model_2.save('patent_2.model')
    optimal_model_3.save('patent_3.model')
# Out:
# C:\Users\Annie\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Visualize the LDA model

# %%
#lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=20, id2word=dictionary, passes=100, workers=8)
# Out:
# C:\Users\Annie\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#coherencemodel = CoherenceModel(model=lda_model, texts=processed_docs, dictionary=dictionary, coherence='c_v')
#coherencemodel.get_coherence()
# Out:
# C:\Users\Annie\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis

vis_data_1 = gensimvis.prepare(topic_model=optimal_model_1, corpus=bow_corpus_1, dictionary=optimal_model_1.id2word)
pyLDAvis.enable_notebook()
pyLDAvis.display(vis_data_1)
# Out:
# C:\Users\Annie\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1522017872886570247537498385"></div>
# <script type="text/javascript">
#
# var ldavis_el1522017872886570247537498385_data = {"mdsDat": {"x": [-0.1441471461118204, 0.34057968066668876, -0.11748830155529129, -0.060491995881086634, -0.018452237118490245], "y": [0.17218486419402726, 0.015178933455135707, -0.14539294567055905, -0.042671370228614336, 0.0007005182500104726], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [44.89528085064675, 31.258340904929018, 14.719773028730042, 6.848015326247362, 2.278589889446832]}, "tinfo": {"Term": ["hydrogen", "mm", "amino_acid", "methyl", "sequenc", "prostat_cancer", "nucleic_acid", "androgen", "nitrogen", "salt", "atom", "protein", "oxygen", "diseas", "prostat", "patient", "nf", "antigen", "mrna", "subject", "alpha", "gene", "object", "antibodi", "anti", "cytotox", "cor", "therapi", "oral", "vector", "amino_acid", "polypeptid", "retinoblastoma", "adenovirus", "viral", "access", "neoplast", "delet", "carcinoma", "plasmid", "pharmacolog", "insert", "promot", "antibodi", "protein", "vector", "infus", "bp", "virus", "pancreat_cancer", "ovarian_cancer", "immunoglobulin", "sarcoma", "breast", "monoclon_antibodi", "nucleotid", "anti", "regimen", "melanoma", "brain_tumor", "nucleic_acid", "dna", "sequenc", "therapi", "antigen", "rang", "host", "recombin", "mg", "isol", "receptor", "hydrogen", "mm", "methyl", "nitrogen", "atom", "salt", "oxygen", "cor", "nucleus", "os", "steroid", "amin", "hydrocarbon", "bromin", "iodin", "dot", "androgen", "exacerb", "antiandrogen", "analog", "agonist", "iodid", "chlorid", "water", "seborrhea", "parent", "affin", "precoci_puberti", "alopecia", "acquir", "receptor", "isol", "diseas", "object", "tissu", "mg", "associ", "nf", "cytotox", "sirna", "dinucleotid", "cpg", "conjunct", "process", "cpg_island", "alpha", "polymorph", "vegf", "mrna", "genom", "biallel", "regulatori_region", "rnai", "hybrid", "genet", "diagnosi", "probe", "enzym", "test", "aggress", "oligonucleotid_probe", "onset", "angiogenesi", "pathogen", "indic", "restrict_enzym", "cytosin", "gene", "object", "subject", "sequenc", "prostat_cancer", "marker", "nucleic_acid", "associ", "recombin", "anti", "protein", "diseas", "vector", "analysi", "psa", "bph", "stem_cell", "neoplasia", "upregul", "malign", "in_situ", "prostat_gland", "epithelium", "gland", "chromosom", "contrast", "xenograft", "homolog", "intraepitheli", "polyclon", "pin", "monoclon", "famili", "fluoresc_in_situ_hybrid", "basal_cell", "linkag", "immunolog", "prostat_cancer", "prostat", "marker", "assay", "molecul", "stag", "antigen", "gene", "androgen", "sequenc", "mrna", "antibodi", "protein", "nucleic_acid", "amino_acid", "condit", "benign_prostat_hyperplasia", "allel", "prognosi", "immun", "isol", "essenti", "oral", "absorb", "absorpt", "advers_reaction", "allerg_reaction", "drug_resist", "gastrointestin_tract", "metabol", "antineoplast", "side_effect", "toxic", "blood", "substanc", "factor", "parenter", "patient", "medic", "enzym", "condit", "diseas", "therapi", "chromosom", "contrast", "xenograft", "in_situ", "prostat_gland", "epithelium", "pin", "gland", "famili", "subject", "util", "test", "object", "receptor", "biopsi", "gastrointestin", "neck", "plan"], "Freq": [102.0, 54.0, 67.0, 34.0, 38.0, 16.0, 63.0, 21.0, 20.0, 18.0, 18.0, 45.0, 17.0, 13.0, 9.0, 5.0, 8.0, 9.0, 9.0, 9.0, 8.0, 10.0, 13.0, 16.0, 28.0, 7.0, 12.0, 7.0, 2.0, 24.0, 65.0136503673193, 11.298239769500219, 10.372147797574055, 9.446055231081424, 9.446055231081424, 7.593869503529696, 7.593864152431496, 6.667779909869398, 6.667779909869398, 6.6677787207364645, 4.8155947768841365, 4.8155947768841365, 10.372234604278187, 15.002096330043555, 40.00884843768674, 21.48586743154748, 3.889501913108272, 3.889501913108272, 3.889501913108272, 3.8895016158250386, 3.8895016158250386, 3.8895007239753387, 3.8894983457094723, 3.8894983457094723, 3.8894956701603722, 9.446345974083618, 25.190703837627858, 8.520127359500057, 2.9634081574827076, 2.9634081574827076, 49.26944471279052, 6.667917254723195, 18.705552152788368, 5.741253904422577, 6.6674344667522 ...

# %%
vis_data_2 = gensimvis.prepare(topic_model=optimal_model_2, corpus=bow_corpus_2, dictionary=optimal_model_2.id2word)
pyLDAvis.enable_notebook()
pyLDAvis.display(vis_data_2)
# Out:
# C:\Users\Annie\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1522017872193115201468243495"></div>
# <script type="text/javascript">
#
# var ldavis_el1522017872193115201468243495_data = {"mdsDat": {"x": [0.10556926853779193, 0.16907861422198844, 0.07936144361363785, -0.16258343364676892, -0.1914258927266494], "y": [0.13031015311841185, -0.1970719782743907, 0.12349135278060536, -0.03800102675289217, -0.0187285008717343], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [38.23502944443697, 30.38574811328445, 20.79650966495672, 7.128964982012642, 3.453747795309223]}, "tinfo": {"Term": ["toxin", "diphtheria", "antibodi", "mm", "salt", "os", "gene", "epitop", "atom", "link", "scaffold", "il", "oxygen", "poli", "nitrogen", "amino_acid", "mi", "prodrug", "express", "specif", "cell", "tumor", "linkag", "wt", "residu", "transcript", "bioactiv", "affin", "amin", "cor", "scaffold", "bioactiv", "gene", "indic", "test", "transcript", "express", "regener", "autoimmun_diseas", "viral_infect", "immun_respons", "translat", "nucleic_acid", "stem_cell", "resid", "promot", "adhes", "dna", "cdna", "librari", "prognosi", "tempor", "interferon", "intern", "inflamm", "peptid", "neurotransmitt", "ribosom", "isol", "immunotherapi", "differenti", "factor", "blood", "diagnosi", "tumor", "tissu", "diseas", "cell", "subject", "patient", "antigen", "rna", "sequenc", "therapeut", "antibodi", "cancer", "associ", "toxin", "diphtheria", "il", "wt", "mutat", "mg", "dt", "lymphoma", "epitop", "malign", "peg", "encapsul", "cell_lymphoma", "melanoma", "residu", "squamous_cell_carcinoma", "cutan", "lung_cancer", "ovarian_cancer", "mutant", "tabl", "brain_tumor", "pancreat_cancer", "leukemia", "colon_cancer", "carcinoma", "csf", "egf", "relaps", "endometrium", "molecul", "endotheli", "amino_acid", "cancer", "cell", "anti", "protein", "tumor", "poli", "polypeptid", "sequenc", "antibodi", "diseas", "antigen", "blood", "mi", "bicarbon", "mab", "transgen", "anesthet", "affin", "assay", "ortholog", "generic", "ra", "nucleotid", "neoplasm", "chronic", "immunoglobulin", "acut", "pain", "monoclon_antibodi", "diabet_nephropathi", "cardiovascular_diseas", "obes", "diabet", "access", "retinopathi", "anesthesia", "hemi", "recombin", "kidney", "inflammatori_respons", "trauma", "acut_lymphoblast_leukemia", "antibodi", "specif", "organ", "associ", "salt", "liver", "amino_acid", "sequenc", "patient", "subject", "polypeptid", "cell", "domain", "tissu", "antigen", "host", "cancer", "cor", "amin", "benzodiazepin", "oxygen", "sulfonamid", "nitrogen", "linkag", "atom", "abnorm", "optic", "depress", "polymorph", "anxieti", "panic", "dysphoria", "psychiatr", "stress", "phobia", "dimer", "object", "hypotens", "diuret", "patholog", "antibacteri", "in_situ", "osteoporosi", "prolif", "link", "cytotox", "poli", "mm", "salt", "cell", "prodrug", "therapeut", "amino_acid", "peptid", "polypeptid", "in_vitro", "in_vivo", "pain", "os", "methyl", "prodrug", "mm", "topoisomeras", "cm", "infect", "hsp", "salt", "prolif", "peripher", "atom", "cytokin", "nitrogen", "hypotens", "diuret", "patholog", "antibacteri", "in_situ", "osteoporosi", "alkyl_group", "chf", "fgfr", "pat", "tyrosin", "extens", "post", "cell_stem", "biotin", "strain", "blood", "express", "cancer", "cell", "cf", "ph", "organ", "therapi", "neoplasm", "generic", "ra", "therapeut", "diseas", "receptor"], "Freq": [128.0, 87.0, 105.0, 31.0, 35.0, 16.0, 69.0, 57.0, 20.0, 24.0, 53.0, 39.0, 14.0, 26.0, 15.0, 74.0, 23.0, 10.0, 43.0, 39.0, 258.0, 109.0, 11.0, 25.0, 36.0, 36.0, 29.0, 16.0, 8.0, 8.0, 52.43412282105009, 29.109261959507506, 68.29545635433848, 19.779310297424807, 17.91331996500827, 34.707438602775014, 41.23870818873168, 12.31535906081474, 12.315356537550718, 11.382363263790465, 10.449366835950183, 9.516371669741915, 21.645434362834575, 8.583380919245684, 7.650385753037415, 6.717389956013139, 6.717389956013139, 6.717385540301098, 6.717381124589058, 6.717381124589058, 5.7843910049088345, 4.851397415740578, 4.851397415740578, 4.851397415740578, 11.382425083759031, 19.779300204368717, 3.9184009879002972, 3.9184000416762883, 3.9184000416762883, 3.918400041676288 ...

# %%
vis_data_3 = gensimvis.prepare(topic_model=optimal_model_3, corpus=bow_corpus_3, dictionary=optimal_model_3.id2word)
pyLDAvis.enable_notebook()
pyLDAvis.display(vis_data_3)
# Out:
# C:\Users\Annie\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el152201787219311632854157766"></div>
# <script type="text/javascript">
#
# var ldavis_el152201787219311632854157766_data = {"mdsDat": {"x": [0.3831320021711348, -0.10225352368018363, -0.09706715901219827, -0.06127562040078899, -0.07838571058721039, -0.04414998849075339], "y": [0.02562539549006395, 0.02756942551595242, 0.27998746707639544, -0.05248374943691587, -0.13348450023295036, -0.1472140384125455], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [23.59349101717676, 20.447169883092606, 15.769542217569663, 14.809752121290776, 14.517710859160623, 10.86233390170957]}, "tinfo": {"Term": ["methyl", "cell", "oxi", "polypeptid", "hydrogen", "antibodi", "icd", "amino_acid", "il", "cryopreserv", "mycoplasma", "virus", "peg", "adi", "tumor", "arginin", "ib", "patient", "subject", "isol", "specif", "anti", "polymorph", "mm", "endogen", "salt", "death", "al", "et", "immunotherapi", "methyl", "oxi", "ib", "hydrogen", "primari_tumor", "asthma", "autoimmun", "cervic", "chronic_obstruct_pulmonari_diseas", "crohn_diseas", "gastrointestin_stromal_tumor", "hepat", "lupus", "mast_cell", "mastocytosi", "metabol", "multipl_myeloma", "multipl_sclerosi", "nephriti", "osteoarthr", "osteosarcoma", "pyrimidin", "rheumatoid_arthriti", "bone", "osteoporosi", "aberr", "alkyl_group", "append", "etiolog", "mutant", "non_small_cell_lung_cancer", "leukemia", "salt", "renal_cancer", "carcinoma", "diseas", "mm", "metastasi", "pancreat_cancer", "breast_cancer", "patient", "tumor", "thyroid", "colon_cancer", "ovarian_cancer", "melanoma", "lung_cancer", "test", "il", "al", "et", "lipid", "domain", "cation", "neck", "monoclon_antibodi", "probe", "prophylact", "receptor", "hybridoma", "water", "breast", "prostat_gland", "cancer_gastric", "colon", "proc", "cancer_kidney", "brain", "urinari", "lung", "pat", "accessori", "cancer_cervic", "skin", "interleukin", "recipi", "hyaluron_acid", "uterus", "parenter", "associ", "antibodi", "adjuv", "condit", "cytotox", "therapeut", "poli", "protein", "melanoma", "cell", "residu", "prostat_cancer", "antigen", "express", "specif", "molecul", "polypeptid", "patient", "death", "icd", "cryopreserv", "puls", "dendrit_cell", "vaccin", "temperatur", "cancer_antigen", "util", "process", "phenotyp", "stage", "photodynam_therapi", "cell", "immunotherapi", "cultur", "death", "gamma_ray", "potassium", "irradi", "genotyp", "cardiac", "anthracyclin", "pharmacolog", "incub", "reagent", "microb", "alcohol", "bridg", "oxygen", "antigen", "nitrogen", "specif", "egfr", "antagonist", "express", "diseas", "subject", "tumor", "ovarian_cancer", "lung_cancer", "prostat_cancer", "patient", "cdc", "cd", "ar", "replic", "virus", "tabl", "meningioma", "delet", "insert", "cancer_rectal", "vesicular", "pituitari_adenoma", "lymphoma_non_hodgkin", "neuroblastoma", "medulloblastoma", "fibrosarcoma", "cancer_ovarian", "epidermoid_carcinoma", "astrocytoma", "squamous_cell_carcinoma", "schwannoma", "cancer_bone", "csf", "ependymoma", "oligodendroglioma", "synthesi", "gastric_cancer", "serum", "blood", "mutat", "tumor", "subject", "mm", "salt", "antibodi", "specif", "isol", "patient", "therapeut", "protein", "gene", "in_vivo", "diseas", "cell", "express", "molecul", "immunotherapi", "sequenc", "nucleic_acid", "amino_acid", "endogen", "phosphoryl", "cytoplasm", "nucleus", "polypeptid", "allel", "longev", "serin", "proteas", "health", "lys", "translat", "viral", "post", "amino_acid", "prolif", "exogen", "mrna", "transgen", "atom", "antisens", "motor", "attenu", "muscl", "sirna", "shrna", "pox_virus", "retrovirus", "mirna", "malign", "nucleic_acid", "vector", "gene", "vaccinia", "metastasi", "express", "subject", "tumor", "residu", "virus", "associ", "cell", "mm", "molecul", "mycoplasma", "adi", "arginin", "peg", "mg", "polymorph", "sodium", "amelior", "symptom", "lysin", "lymphocyt", "compress", "progress", "chronic_myelogen_leukemia", "relaps", "small_cell_lung_cancer", "anti", "tablet", "isol", "testicular_cancer", "glioma", "kidney_cancer", "stomach_cancer", "cystein", "uterin_cancer", "leukemia_acut_myeloid", "acu ...
